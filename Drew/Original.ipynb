# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import requests
import csv
import json

# %% [markdown]
# ## Product IDs For Women's Shoes

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/100001606"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()
json
# Out:
# {'code': 200,
#  'cost': 611,
#  'data': {'abVersion': '1',
#   'crawler': False,
#   'searchResult': {'mods': {'searchRapidFilters': {'content': [{'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'mall_tag_switch',
#          'switchTag': {'displayTagType': 'text', 'tagText': 'PLUS'},
#          'selectedValue': 'mall:true',
#          'selected': False},
#         {'switchType': 'free_shipping_switch',
#          'switchChosenTag': {'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'switchTag': {'displayTagType': 'text', 'tagText': 'Free Shipping'},
#          'selectedValue': 'freeshipping:true',
#          'selected': False}]}]},
#     'searchRefineFilters': {'content': [{'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'shpf_co',
#        'type': 'logistics',
#        'title': 'Ship From',
#        'tItemType': 'search_refine_logistics',
#        'content': [{'countryCode': 'US',
#          'countryName': 'United States',
#          'selected': False},
#         {'countryCode': 'TR', 'countryName': 'Turkey', 'selected': False},
#         {'countryCode': 'CN', 'countryName': 'China', 'selected': False}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': True,
#        'loadFilter': True,
#        'refineTiling': False,
#        'paramName': 'cid',
#        'type': 'category',
#        'title': 'Categories',
#        'tItemType': 'search_refine_category',
#        'content': [{'categoryEnName': "Women's Shoes",
#          'categoryMultiName': "Women's Shoes",
#          'leafCategory': False,
#          'categoryId': 100001606,
#          'selected': True}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'bids',
#        'type': 'brandWall',
#        'title': 'Brands',
#        'tItemType': 'search_refine_brandwall',
#        'content': [{'brandName': 'PUAMSS',
#          'brandId': '202615814',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg'},
#         {'brandName': 'krazing pot',
#          'brandId': '202380086',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1IFlejr_I8KJjy1Xaq6zsxpXaf.jpg'},
#         {'brandName': 'DoraTasia',
#          'brandId': '201689863',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1lR_.elfM8KJjSZPiq6xdspXaA.jpg'},
#         {'brandName': 'MORAZORA',
#          'brandId': '201605913',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1CYg6QFXXXXXAaXXX760XFXXX3.png'},
#         {'brandName': 'BeauToday',
#          'brandId': '201465854',
#          'brandLogo': '//ae01.alicdn.com/kf/Sd329a849ab5b4b778b4be655047e50d8L.png'}]},
#       {'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'user_favorite_switch',
#          'switchChosenTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'switchTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'selectedValue': 'pop:true',
#          'selected': False}]},
#       {'minTips': 'Min.',
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'currencySymbol': 'US $',
#        'refineTiling': False,
#        'paramName': 'pr',
#        'maxTips': 'Max',
#        'type': 'priceRange',
#        'title': 'Price',
#        'tItemType': 'search_refine_pricerange',
#        'content': [{'startPrice': '7.25',
#          'priceRanges': '7.25-13.67',
#          'endPrice': '13.67',
#          'boughtRate': 'Chosen by35%',
#          'selected': False},
#         {'startPrice': '13.67',
#          'priceRanges': '13.67-37.37',
#          'endPrice': '37.37',
#          'boughtRate': 'Chosen by40%',
#          'selected': False},
#         {'startPrice': '37.37',
#          'priceRanges': '37.37-76.64',
#          'endPrice': '76.64',
#          'boughtRate': 'Chosen by11%',
#          'selected': False}],
#        'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False},
#       {'paramType': 'List',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'attr',
#        'type': 'attribute',
#        'title': 'Attribute',
#        'tItemType': 'search_refine_attribute',
#        'content': [{'attributeId': 200000124,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 100010487,
#            'attributeValueName': '44'},
#           {'attributeValueId': 100010483, 'attributeValueName': '41'},
#           {'attributeValueId': 1583, 'attributeValueName': '10'},
#           {'attributeValueId': 100010420, 'attributeValueName': '11'},
#           {'attributeValueId': 100010386, 'attributeValueName': '19'},
#           {'attributeValueId': 100010384, 'attributeValueName': '17'},
#           {'attributeValueId': 100010385, 'attributeValueName': '18'},
#           {'attributeValueId': 1394, 'attributeValueName': '6'},
#           {'attributeValueId': 1663, 'attributeValueName': '12'},
#           {'attributeValueId': 153, 'attributeValueName': '4'}],
#          'attributeName': 'Shoe Size'},
#         {'attributeId': 14,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 193,
#            'attributeValueName': 'Black'},
#           {'attributeValueId': 200002984, 'attributeValueName': 'Burgundy'},
#           {'attributeValueId': 201496390, 'attributeValueName': 'Rosy Red'},
#           {'attributeValueId': 201302648, 'attributeValueName': 'rose'},
#           {'attributeValueId': 100018786, 'attributeValueName': 'Clear'},
#           {'attributeValueId': 200003699, 'attributeValueName': 'MULTI'},
#           {'attributeValueId': 1052, 'attributeValueName': 'Pink'},
#           {'attributeValueId': 29, 'attributeValueName': 'White'},
#           {'attributeValueId': 200141872, 'attributeValueName': 'Deep Purple'},
#           {'attributeValueId': 1254, 'attributeValueName': 'Sky blue'},
#           {'attributeValueId': 173, 'attributeValueName': 'Blue'},
#           {'attributeValueId': 200004870, 'attributeValueName': 'Deep Blue'},
#           {'attributeValueId': 175, 'attributeValueName': 'Green'},
#           {'attributeValueId': 496, 'attributeValueName': 'purple'},
#           {'attributeValueId': 200004891, 'attributeValueName': 'Lavender'},
#           {'attributeValueId': 200004890, 'attributeValueName': 'Dark Grey'},
#           {'attributeValueId': 691, 'attributeValueName': 'Gray'},
#           {'attributeValueId': 200001438, 'attributeValueName': 'Khaki'},
#           {'attributeValueId': 200002130, 'attributeValueName': 'Ivory'}],
#          'attributeName': 'Color'},
#         {'attributeId': 20698,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002429,
#            'attributeValueName': 'Mesh (Air mesh)'},
#           {'attributeValueId': 365601, 'attributeValueName': 'Lace'},
#           {'attributeValueId': 365230, 'attributeValueName': 'Silk'},
#           {'attributeValueId': 571, 'attributeValueName': 'microfiber'},
#           {'attributeValueId': 63, 'attributeValueName': 'nylon'},
#           {'attributeValueId': 452, 'attributeValueName': 'PU'},
#           {'attributeValueId': 200004384,
#            'attributeValueName': 'Sequined Cloth'},
#           {'attributeValueId': 200001597,
#            'attributeValueName': 'Patent Leather'},
#           {'attributeValueId': 1886, 'attributeValueName': 'Corduroy'},
#           {'attributeValueId': 200004382, 'attributeValueName': 'flock'},
#           {'attributeValueId': 200004381, 'attributeValueName': 'Cloth'},
#           {'attributeValueId': 123, 'attributeValueName': 'Rubber'}],
#          'attributeName': 'Upper Material'}]}]},
#     'sortBar': {'tItemType': 'nt_mainsearch_sortbar',
#      'content': [{'sortOrders': [{'selected': True, 'order': 'default'}],
#        'sortType': 'default',
#        'sortMultiCopy': 'Best matches'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'orders',
#        'sortMultiCopy': 'Orders'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'price',
#        'sortMultiCopy': 'Price (High to Low)'},
#       {'sortOrders': [{'selected': False, 'order': 'asc'}],
#        'sortType': 'price',
#        'sortMultiCopy': 'Price (Low to High)'}]},
#     'itemList': {'content': [{'lunchTime': '2022-10-31 00:00:00',
#        'image': {'imgUrl': '//ae04.alicdn.com/kf/Seaf59e027751445ebdd94c4f102e85977.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed
XCkP03vmJ3LOanZe6FOU5i-f1kMloObWNql9EI-C9GP8vfSPNEMzaRr4Wo5XakJj.ho0klrSIJCALyNMuU8m5T.e6ZoOLyiGdUifVViKwvjyGwNer9yQbVqJr460QuV2OAFkIVTgDVUuOFLVJ38moLmJYx9riw9WiW3Mdy6bMdqo4lSHuL8XhPWB1V.NKZ7hDWpERTdJP6XSz19vNLs8&ap=1&rp=1',
#         'adTag': {'tagStyle': {'backgroundColor': 'rgba(0,0,0,0.20)'},
#          'displayTagType': 'text',
#          'tagText': 'AD'},
#         'sessionId': '2022111506305311037399104721420000673427'},
#        'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 4.9,
#         'starHeight': 30},
#        'lunchTime': '2022-05-04 00:00:00',
#        'trace': {'exposure': {'session_id': '2022111506305311037399104721420000673427',
#          'selling_point': '885603828,885603359',
#          'aem_p4p_exposure': '1005004243173758',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-2'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'aem_p4p_detail': '2022111506305311037399104721420000673427',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-2'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804056859006%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000028501929819%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2257%22%2C%22star%22%3A%224.9%22%2C%22shippingFee%22%3A%228.35%22%7D',
#          'pdp_npi': '2%40dis%21USD%2115.29%219.17%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000028501929819%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'aem_p4p_click': '1005004243173758',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $9.17',
#          'csp': '9.17,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'session_id': '2022111506305311037399104721420000673427',
#          'sku_id': '12000028501929819',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'new_user_discount,flexiCoin',
#          'oip': '15.29,0',
#          'selling_point': '885603828,885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004243173758'}},
#        'trade': {'tradeDesc': '57 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $9.17',
#          'minPriceDiscount': 40,
#          'minPrice': 9.17,
#          'priceType': 'sale_price',
#          'discount': 40,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000028501929819'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'New User Deal'},
#          'position': 3,
#          'source': 'new_user_discount',
#          'sellingPointTagId': '885603828',
#          'group': 3},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $8.35'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'ad'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 5.0,
#         'starHeight': 30},
#        'lunchTime': '2021-10-28 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/Sd99361f918464457a9e1a998ab3fb780z.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-3'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-3'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256803290146743%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000025961149052%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22105%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2144.35%2135.48%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000025961149052%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $35.48',
#          'csp': '35.48,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.07854348421096802,
#          'sku_id': '12000025961149052',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '44.35,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003476461495'}},
#        'trade': {'tradeDesc': '105 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256803290146743',
#        'title': {'displayTitle': '2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX',
#         'shortTitle': False,
#         'seoTitle': '2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $35.48',
#          'minPriceDiscount': 20,
#          'minPrice': 35.48,
#          'priceType': 'sale_price',
#          'discount': 20,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000025961149052'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 4.9,
#         'starHeight': 30},
#        'lunchTime': '2022-06-01 00:00:00',
#        'image': {'imgUrl': '//ae04.alicdn.com/kf/Sc7b2aa3e2e144d8d945d405a27fbcc2bw.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-4'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-4'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804146039143%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000028888819519%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22542%22%2C%22star%22%3A%224.9%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%218.84%218.84%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000028888819519%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $8.84',
#          'csp': '8.84,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.10870915651321411,
#          'sku_id': '12000028888819519',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'oip': '8.84,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004332353895'}},
#        'trade': {'tradeDesc': '542 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804146039143',
#        'title': {'displayTitle': 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers',
#         'shortTitle': False,
#         'seoTitle': 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $8.84',
#          'minPrice': 8.84,
#          'priceType': 'sale_price',
#          'minPriceType': 1,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000028888819519'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 5.0,
#         'starHeight': 30},
#        'lunchTime': '2022-09-16 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S561cb363a7a34a778677ae729d37ef2cN.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-5'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-5'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804568740738%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030348977606%22%2C%22shipFrom%22%3A%22%22%2C%22order%22%3A%22226%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2119.98%219.99%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000030348977606%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $9.99',
#          'csp': '9.99,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.14411211013793945,
#          'sku_id': '12000030348977606',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '19.98,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004755055490'}},
#        'trade': {'tradeDesc': '226 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804568740738',
#        'title': {'displayTitle': 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes',
#         'shortTitle': False,
#         'seoTitle': 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $9.99',
#          'minPriceDiscount': 50,
#          'minPrice': 9.99,
#          'priceType': 'sale_price',
#          'discount': 50,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030348977606'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 5.0,
#         'starHeight': 30},
#        'lunchTime': '2022-10-25 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S2027b9c07ef64da5aa864ef3e6bac6340.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-6'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-6'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804697787771%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030883733807%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22449%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2174.99%2166.74%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000030883733807%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $66.74',
#          'csp': '66.74,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.10189011693000793,
#          'sku_id': '12000030883733807',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '74.99,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004884102523'}},
#        'trade': {'tradeDesc': '449 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804697787771',
#        'title': {'displayTitle': '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002',
#         'shortTitle': False,
#         'seoTitle': '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $66.74',
#          'minPriceDiscount': 11,
#          'minPrice': 66.74,
#          'priceType': 'sale_price',
#          'discount': 11,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030883733807'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 5.0,
#         'starHeight': 30},
#        'lunchTime': '2021-11-03 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/H651e2b96b5a34ce1909580c76ede6b2bk.png',
#         'imgWidth': 726,
#         'imgHeight': 672,
#         'imgType': '3'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-7'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-7'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256803313822268%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000026070993679%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22347%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%2210.00%22%7D',
#          'pdp_npi': '2%40dis%21USD%2119.99%2119.99%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000026070993679%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $19.99',
#          'csp': '19.99,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.06158876419067383,
#          'sku_id': '12000026070993679',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'oip': '19.99,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003500137020'}},
#        'trade': {'tradeDesc': '347 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256803313822268',
#        'title': {'displayTitle': 'NEW Winter Keep Warm Women Fur Furry Slippers for Home Fluffy Soft Indoor Slides Non Slip Indoor House Shoes',
#         'shortTitle': False,
#         'seoTitle': 'NEW Winter Keep Warm Women Fur Furry Slippers for Home Fluffy Soft Indoor Slides Non Slip Indoor House Shoes'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $19.99',
#          'minPrice': 19.99,
#          'priceType': 'sale_price',
#          'minPriceType': 1,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000026070993679'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $10.00'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 4.2,
#         'starHeight': 30},
#        'lunchTime': '2022-09-16 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S832d095e3bb2486b8ba1188f53563f50E.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-8'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-8'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804570453332%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030691067574%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%221846%22%2C%22star%22%3A%224.2%22%2C%22shippingFee%22%3A%227.01%22%7D',
#          'pdp_npi': '2%40dis%21USD%2116.8%2111.26%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000030691067574%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $11.26',
#          'csp': '11.26,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.2445245385169983,
#          'sku_id': '12000030691067574',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '16.8,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004756768084'}},
#        'trade': {'tradeDesc': '1846 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804570453332',
#        'title': {'displayTitle': 'New Snow Boot Style Short Mini Winter Sheepskin Boots Women Waterproof Natural Wool Ankle Boots Fur Lined Ankle Warm Flat Shoes',
#         'shortTitle': False,
#         'seoTitle': 'New Snow Boot Style Short Mini Winter Sheepskin Boots Women Waterproof Natural Wool Ankle Boots Fur Lined Ankle Warm Flat Shoes'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $11.26',
#          'minPriceDiscount': 33,
#          'minPrice': 11.26,
#          'priceType': 'sale_price',
#          'discount': 33,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030691067574'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $7.01'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'lunchTime': '2022-10-19 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S0f2558920a6c4dec870b9be4d5e9441dx.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-9'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-9'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804676766123%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030794271119%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2247%22%2C%22star%22%3A%22%22%2C%22shippingFee%22%3A%226.31%22%7D',
#          'pdp_npi': '2%40dis%21USD%2135.99%2133.11%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000030794271119%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $33.11',
#          'csp': '33.11,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.11818575859069824,
#          'sku_id': '12000030794271119',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '35.99,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004863080875'}},
#        'trade': {'tradeDesc': '47 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256
sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $17.76',
#          'minPriceDiscount': 52,
#          'minPrice': 17.76,
#          'priceType': 'sale_price',
#          'discount': 52,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030419358334'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'New User Deal'},
#          'position': 3,
#          'source': 'new_user_discount',
#          'sellingPointTagId': '885603828',
#          'group': 3},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'ad'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 4.5,
#         'starHeight': 30},
#        'lunchTime': '2022-10-20 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S981da09d2da445dc947a51b3e710cddcN.jpg',
#         'imgWidth': 750,
#         'imgHeight': 750,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-11'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-11'},
# ...
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $20.75',
#          'csp': '20.75,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.10503944754600525,
#          'sku_id': '12000029170184287',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'flexiCoin',
#          'oip': '34.58,0',
#          'selling_point': '8810202851,885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004333279754'}},
#        'trade': {'tradeDesc': '946 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804146965002',
#        'title': {'displayTitle': 'ZZFABER Barefoot Shoes Women Sneakers Flexible Ladies Casual Flats Unisex Aqua Shoes Soft Hiking Sports Running Shoes for Men',
#         'shortTitle': False,
#         'seoTitle': 'ZZFABER Barefoot Shoes Women Sneakers Flexible Ladies Casual Flats Unisex Aqua Shoes Soft Hiking Sports Running Shoes for Men'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $20.75',
#          'minPriceDiscount': 40,
#          'minPrice': 20.75,
#          'priceType': 'sale_price',
#          'discount': 40,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000029170184287'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagImgWidth': 290,
#           'tagImgHeight': 30,
#           'tagStyle': {},
#           'displayTagType': 'image',
#           'tagImgUrl': '//ae01.alicdn.com/kf/H08a2b4d322c5466498dc53c63e90133cM.png'},
#          'dataSourceIds': '1000016818',
#          'position': 2,
#          'sellingPointTagId': '8810202851',
#          'group': 2},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'evaluation': {'starWidth': 33,
#         'starUrl': '//ae01.alicdn.com/kf/HTB1S2ffafvsK1Rjy0Fi762wtXXaS.png',
#         'starRating': 5.0,
#         'starHeight': 30},
#        'lunchTime': '2022-06-27 00:00:00',
#        'image': {'imgUrl': '//ae04.alicdn.com/kf/S232a46f5694f4e64b171de3b6d66fb0c9.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-17'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-17'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804273010958%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000029244972162%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22261%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2139.5%2119.75%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000029244972162%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $19.75',
#          'csp': '19.75,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.12303254008293152,
#          'sku_id': '12000029244972162',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '39.5,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004459325710'}},
#        'trade': {'tradeDesc': '261 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804273010958',
#        'title': {'displayTitle': "2022 Women's Sandals Luxury Brand Summer Fashion Transparent Rhinestone Pointed High Heel 8cm Ladies Sexy High Heels",
#         'shortTitle': False,
#         'seoTitle': "2022 Women's Sandals Luxury Brand Summer Fashion Transparent Rhinestone Pointed High Heel 8cm Ladies Sexy High Heels"},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $19.75',
#          'minPriceDiscount': 50,
#          'minPrice': 19.75,
#          'priceType': 'sale_price',
#          'discount': 50,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000029244972162'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'},
#       {'lunchTime': '2022-09-03 00:00:00',
#        'image': {'imgUrl': '//ae04.alicdn.com/kf/S1c842479dab642a8883dc308020ab4531.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'session_id': '2022111506305311037399104721420000673427',
#          'selling_point': '885603359',
#          'aem_p4p_exposure': '1005004711919838',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-18'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'aem_p4p_detail': '2022111506305311037399104721420000673427',
#          'algo_exp_id': '66cbce8b-1867-4f73-a921-d915e4d624ed-18'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101fd4b16685226536393389e8fcf%22%2C%22itemId%22%3A%223256804525605086%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030194336843%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2212%22%2C%22star%22%3A%22%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2133.06%2116.53%21%21%21%21%21%402101fd4b16685226536393389e8fcf%2112000030194336843%21sea'},
#         'click': {'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'aem_p4p_click': '1005004711919838',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $16.53',
#          'csp': '16.53,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'session_id': '2022111506305311037399104721420000673427',
#          'sku_id': '12000030194336843',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '33.06,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004711919838'}},
#        'trade': {'tradeDesc': '12 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256
},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $49.00',
#          'minPriceDiscount': 50,
#          'minPrice': 49.0,
#          'priceType': 'sale_price',
#          'discount': 50,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000031017906611'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'position': 4,
#          'sellingPointTagId': '885603359',
#          'group': 8}],
#        'productType': 'natural'}]}},
#    '_cost': 593.88373,
#    'pvid': 'f8e1a62b-c270-4e7d-8932-97b1e9ff3c3f',
#    'pageInfo': {'textTitle': 'All filters ',
#     'enableRefineRefactor2': False,
#     'textReset': 'Reset',
#     'textMore': 'See more ',
#     'pageSize': 20,
#     'finished': False,
#     'marketingPeriod': 'daily_period',
#     'searchResultType': 'normal_result',
#     'displayStyle': 'gallery',
#     'filterSelected': False,
#     'totalResults': 550018,
#     'trace': {'translsateTrace': {},
#      'exposure': {},
#      'customPage': {'dis_cat_name': "Women's Shoes",
#       'tpp_access_trace': '18539#69073#297875',
#       'tenant': 'global'},
#      'custom': {},
#      'detailPage': {},
#      'page': {'ab': '6|6|9|9|6|71|10|6|6|8|2|11|13|2|5|12|10|5|1|4|7|8|2',
#       'list_page_type': 'main',
#       'hyperspaceTraceId': '2101fd4b16685226536393389e8fcf',
#       'p4pId': '9ba88b85-2a94-4b7a-a170-e61a9ca6ac09',
#       'algo_pvid': '66cbce8b-1867-4f73-a921-d915e4d624ed',
#       'isAffiliateTraffic': 'false',
#       'btsid': '2101fd4b16685226536393389e8fcf',
#       'pid': '808_0000_0201',
#       'gdpr': '2',
#       'trafficChannel': 'main',
#       'engine': 'ALI',
#       'aem_count': '550018',
#       'tenant': 'CN_CB',
#       'aem_ab': '6|6|9|9|6|71|10|6|6|8|2|11|13|2|5|12|10|5|1|4|7|8|2'},
#      'click': {},
#      'utLogMap': {'bizScene': 'mainSearch',
#       'filter_by': '{"categoryId":"100001606"}',
#       'no_result_tips_pos': 'null',
#       'language': 'en',
#       'sort_by': 'default_default',
#       'newSummaryCouponService': 'true',
#       'tpp_buckets': '687#2842#8085#5_687#2854#8145#6_687#4280#19695#8_687#2166#5614#11_687#2224#18948#1_687#3277#7904402#2_687#2172#5548#2_687#2158#5492#71_687#2163#5563#6_687#2701#26852#12_687#5275#24247#2_687#4837#22323#2_687#2167#5622#8_687#2724#7611#10_687#10162#437639#9_687#3860#17562#6_687#2168#439882#13_687#2497#6797#10_687#7205#34794#4_687#2352#16922#2_687#11988#445784#9_687#11987#445771#6_687#2164#5578#5_687#11744#443786#6_687#2165#5588#7_687#18539#297875#69073',
#       'user_tags': '-29883,NEWUSER',
#       'trafficChannel': 'main',
#       'query_from': 'direct',
#       'pageIndex': '1',
#       'hitDocs': 550018,
#       'traffic_diff_id': 'default',
#       'ui_style': 'sellpoint:default;price:default-soldColor;logistics:default;page:default;media:default;title:default;dimension:default;',
#       'currency': 'USD'}},
#     'enableFilterOnlyRefine': False,
#     'textSearching': 'Searching...',
#     'selectedFilterCount': 1,
#     'textTotalResults': 'Show 550,000+ results ',
#     'success': True,
#     'page': 1,
#     'allResult': 'All results '},
#    'modsStyle': {'price': {'decimal_point': '.',
#      'sold_font_color': '#222222',
#      'comma_style': ',',
#      'symbol_position': 'left'},
#     'page': {'align': 'left'},
#     'title': {'row_cnt': '1'}},
#    '_host': 'hippo.033003005183.us68',
#    'scm': '1007.28539.297875.0',
#    'version': 1.0,
#    'srpResult': [20],
#    'tpp_trace': '2101fd4b16685226536393389e8fcf'},
#   'trafficChannel': 'main'},
#  'success': True}

# %%
## We want 'productID', 'title':'displayTitle', 'prices':'salePrice':'formattedPrice', 'evaluation':'starRating'

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)
# Out:
# 'code,cost,data,success\n200,611,1,True\n200,611,False,True\n200,611,"{\'mods\': {\'searchRapidFilters\': {\'content\': [{\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'mall_tag_switch\', \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'PLUS\'}, \'selectedValue\': \'mall:true\', \'selected\': False}, {\'switchType\': \'free_shipping_switch\', \'switchChosenTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'selectedValue\': \'freeshipping:true\', \'selected\': False}]}]}, \'searchRefineFilters\': {\'content\': [{\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': False, \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'shpf_co\', \'type\': \'logistics\', \'title\': \'Ship From\', \'tItemType\': \'search_refine_logistics\', \'content\': [{\'countryCode\': \'US\', \'countryName\': \'United States\', \'selected\': False}, {\'countryCode\': \'TR\', \'countryName\': \'Turkey\', \'selected\': False}, {\'countryCode\': \'CN\', \'countryName\': \'China\', \'selected\': False}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': True, \'loadFilter\': True, \'refineTiling\': False, \'paramName\': \'cid\', \'type\': \'category\', \'title\': \'Categories\', \'tItemType\': \'search_refine_category\', \'content\': [{\'categoryEnName\': ""Women\'s Shoes"", \'categoryMultiName\': ""Women\'s Shoes"", \'leafCategory\': False, \'categoryId\': 100001606, \'selected\': True}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'bids\', \'type\': \'brandWall\', \'title\': \'Brands\', \'tItemType\': \'search_refine_brandwall\', \'content\': [{\'brandName\': \'PUAMSS\', \'brandId\': \'202615814\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg\'}, {\'brandName\': \'krazing pot\', \'brandId\': \'202380086\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1IFlejr_I8KJjy1Xaq6zsxpXaf.jpg\'}, {\'brandName\': \'DoraTasia\', \'brandId\': \'201689863\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1lR_.elfM8KJjSZPiq6xdspXaA.jpg\'}, {\'brandName\': \'MORAZORA\', \'brandId\': \'201605913\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1CYg6QFXXXXXAaXXX760XFXXX3.png\'}, {\'brandName\': \'BeauToday\', \'brandId\': \'201465854\', \'brandLogo\': \'//ae01.alicdn.com/kf/Sd329a849ab5b4b778b4be655047e50d8L.png\'}]}, {\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'user_favorite_switch\', \'switchChosenTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'switchTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'selectedValue\': \'pop:true\', \'selected\': False}]}, {\'minTips\': \'Min.\', \'existSelectedValue\': False, \'loadFilter\': False, \'currencySymbol\': \'US $\', \'refineTiling\': False, \'paramName\': \'pr\', \'maxTips\': \'Max\', \'type\': \'priceRange\', \'title\': \'Price\', \'tItemType\': \'search_refine_pricerange\ ...

# %%
compression_opts = dict(method='zip',
...                         archive_name='out.csv')  
>>> df.to_csv('out.zip', index=False,
...           compression=compression_opts)

# %%
from pathlib import Path  
>>> filepath = Path('out.csv')  
>>> filepath.parent.mkdir(parents=True, exist_ok=True)  
>>> df.to_csv(filepath)

# %%
# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   611     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'lunchTime': '2022-10-31 00:00:00', 'image':...  ...
#
#    data.searchResult.modsStyle.price.comma_style  \
# 0                                              ,
#
#   data.searchResult.modsStyle.price.symbol_position  \
# 0                                              left
#
#   data.searchResult.modsStyle.page.align  \
# 0                                   left
#
#    data.searchResult.modsStyle.title.row_cnt  data.searchResult._host  \
# 0                                          1  hippo.033003005183.us68
#
#   data.searchResult.scm  data.searchResult.version  \
# 0   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  2101fd4b16685226536393389e8fcf
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 74 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]
df
# Out:
#              data.searchResult.mods.itemList.content
# 0  [{'lunchTime': '2022-10-31 00:00:00', 'image':...

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['title']))
# Out:
# {'displayTitle': '2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini', 'shortTitle': False, 'seoTitle': '2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini'}

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

productId = ((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))
title = ((df["data.searchResult.mods.itemList.content"].values[0][0]['title']))

productId_list = []
title_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)
# Out:
# 3256804718617801
# ['3256804718617801', '3256804640578331', '3256804056859006', '3256803290146743', '3256804146039143', '3256804568740738', '3256804697787771', '3256803313822268', '3256804570453332', '3256804676766123', '3256804585761282', '3256804679939115', '3256802423567155', '3256804603507576', '3256803920114904', '3256804428351342', '3256804146965002', '3256804273010958', '3256804525605086', '3256804732539915']

# %%
for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)
# Out:
# ['2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini', "Muller shoes women's plush slippers 2021 autumn and winter new flat shoes horsebit buckle female Baotou semi-drag flat shoes", '2022 Summer Women Shoes Breathable Mesh Outdoor Light Weight Sports Shoes Casual Walking Sneakers Tenis Feminino Zapatos Mujer', '2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX', 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers', 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes', '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002', 'NEW Winter Keep Warm Women Fur Furry Slippers for Home Fluffy Soft Indoor Slides Non Slip Indoor House Shoes', 'New Snow Boot Style Short Mini Winter Sheepskin Boots Women Waterproof Natural Wool Ankle Boots Fur Lined Ankle Warm Flat Shoes', '2022 Leather slippers for women in the summer of wear tendon soft beach shoes gs-028', "Luxury Brand 2023 New Women   Thick - soled Thick - heeled Warm   Boots Women ' s Towel Cotton Boots   Motorcycle Boots", "LEOPARD LAND Girls' Lolita Shoes Women PU Thick Sole Students JK Uniform Mary Jane Shoes Japanese Cosplay Vintage Fashion HYGC", '2021 Fashion Women Black Sneakers 44 Chaussure Femme Women Sneakers Zipper Canvas Casual Shoes Woman Spring Ladies Shoe', 'White Women Platform Boots Women Casual Shoes Genuine Leather Thick Sole Ladies Girl Female Motorcycle Combat Ankle Boots', "2022 Fashion Design Bright Leather Med Heel Women's Shoes Made by Cowhide Leather Soft Comfortable Shoes for Women Size 35 to 42", '2022 the new leisure shoes lazy flat shoes', 'ZZFABER Barefoot Shoes Women Sneakers Flexible Ladies Casual Flats Unisex Aqua Shoes Soft Hiking Sports Running Shoes for Men', "2022 Women's Sandals Luxury Brand Summer Fashion Transparent Rhinestone Pointed High Heel 8cm Ladies Sexy High Heels", 'Platform Sports Shoes Outdoor Fitness Breathable Casual Lace-up Running Women Flat Lightweight Zapatillas De Deporte Para Mujer', 'So Kate Red High Heel Shoes Brand Pumps Sexy Red Bottoms Pointed Toe Thin Heel 8cm 10cm 12cm Shallow Sexy Wedding Shoes + Box']

# %%
price_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)
# Out:
# ['US $54.48', 'US $46.20', 'US $9.17', 'US $35.48', 'US $8.84', 'US $9.99', 'US $66.74', 'US $19.99', 'US $11.26', 'US $33.11', 'US $17.76', 'US $13.61', 'US $27.49', 'US $43.78', 'US $108.00', 'US $30.44', 'US $20.75', 'US $19.75', 'US $16.53', 'US $49.00']

# %%
star_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['sellingPoints']['evaluation']['starRating']))
    star_list.append(each_value)
    
print(star_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/lh/b41zj8m157b89wb32ykjqsbm0000gn/T/ipykernel_42407/584271995.py in <module>
#       2
#       3 for i in range (20):
# ----> 4     each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['sellingPoints']['evaluation']['starRating']))
#       5     star_list.append(each_value)
#       6
#
# TypeError: list indices must be integers or slices, not str

# %%
## Create dataframe with women's shoes product ids, titles, prices, and star ratings.

# %% [markdown]
# ## Product IDs For Women's Boots

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200216407"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out1.csv')  
df.to_csv('out1.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out1.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out1.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
wboots_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
wboots_productIds

# %% [markdown]
# ## Product IDs For Women's Flats

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200002155"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
wflats_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
wflats_productIds

# %% [markdown]
# ## Product IDs For Men's Shoes

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/100001615"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
mshoes_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
mshoes_productIds

# %% [markdown]
# ## Combine All Categories

# %%
data = np.array([[3256802423567155,
 3256803147612333,
 3256803313822268,
 3256803613454020,
 3256804146039143,
 3256804273010958,
 3256804288091339,
 3256804340338295,
 3256804374631137,
 3256804549567127,
 3256804564507961,
 3256804598834886,
 3256804600087452,
 3256804603507576,
 3256804606583693,
 3256804627451745,
 3256804679939115,
 3256804683170661,
 3256804697787771,
 3256804718617801], 
[3256803899670216,
 3256803910990175,
 3256804274369718,
 3256804288091339,
 3256804339852643,
 3256804374631137,
 3256804390450457,
 3256804419670610,
 3256804465546586,
 3256804536446371,
 3256804549567127,
 3256804603507576,
 3256804635290857,
 3256804676604636,
 3256804696130563,
 3256804698461319,
 3256804706160135,
 3256804710640068,
 3256804718617801,
 3256804728034603],
[3256802423567155,
 3256803290146743,
 3256803298586233,
 3256803305179821,
 3256803443967583,
 3256803448034929,
 3256803613454020,
 3256803636531347,
 3256803958419735,
 3256804096886433,
 3256804146965002,
 3256804520151422,
 3256804538602358,
 3256804583276496,
 3256804627451745,
 3256804679939115,
 3256804680467020,
 3256804683170661,
 3256804683702066,
 3256804697787771],
[2255800565385191,
 3256803193913624,
 3256803288474366,
 3256803380552863,
 3256803456568863,
 3256803852328051,
 3256804288946512,
 3256804345871208,
 3256804389102849,
 3256804398579682,
 3256804399002172,
 3256804456692695,
 3256804548714244,
 3256804558295955,
 3256804564507961,
 3256804588660403,
 3256804602698717,
 3256804622918647,
 3256804704992185,
 3256804705540267]])

dataset = pd.DataFrame({'Womens Shoes': data[0], 'Womens Boots': data[1], 'Women Flats': data[2], 'Mens Shoes': data[3]})
print(dataset)

# %%
df = pd.DataFrame(dataset)
df

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='productIds_bycategory.csv')  
df.to_csv('productIds_bycategory.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('productIds_bycategory.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)

# %% [markdown]
# ## Creating Product Feedback Database
# ### Plug in product IDs to compile and compare feedback within and between categories
# #### Keys to compare: "data.evaViewList.[0].buyerFeedback",  "data.evaViewList.[0].images", "data.productEvaluationStatistic."

# %%
url = "https://ali-express1.p.rapidapi.com/product/3256802423567155/feedback/"

querystring = {"country":"us","page":"1","type":"all"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.evaViewList',
'data.productEvaluationStatistic.evarageStar',
'data.productEvaluationStatistic.evarageStarRage',
'data.productEvaluationStatistic.fiveStarNum',
'data.productEvaluationStatistic.fiveStarRate',
'data.productEvaluationStatistic.fourStarNum',
'data.productEvaluationStatistic.fourStarRate',
'data.productEvaluationStatistic.negativeNum',
'data.productEvaluationStatistic.negativeRate',
'data.productEvaluationStatistic.neutralNum',
'data.productEvaluationStatistic.neutralRate',
'data.productEvaluationStatistic.oneStarNum',
'data.productEvaluationStatistic.oneStarRate',
'data.productEvaluationStatistic.positiveNum',
'data.productEvaluationStatistic.positiveRate',
'data.productEvaluationStatistic.threeStarNum',
'data.productEvaluationStatistic.threeStarRate',
'data.productEvaluationStatistic.totalNum',
'data.productEvaluationStatistic.twoStarNum',
'data.productEvaluationStatistic.twoStarRate',]]
        
df

# %%
print((df["data.evaViewList"].values[0][0]['buyerFeedback']))

# %%
print((df["data.evaViewList"].values[0][0]['images']))

# %% [markdown]
# ### Ended up pasting feedback results per product id into csv files for each category

# %%
# df.to_excel("output.xlsx",
#              sheet_name='Sheet_name_1')

# %% [markdown]
#  ## Product IDs

# %%
 
    Womens Shoes      Womens Boots       Women Flats        Mens Shoes
0   3256802423567155  3256803899670216  3256802423567155  2255800565385191
1   3256803147612333  3256803910990175  3256803290146743  3256803193913624
2   3256803313822268  3256804274369718  3256803298586233  3256803288474366
3   3256803613454020  3256804288091339  3256803305179821  3256803380552863
4   3256804146039143  3256804339852643  3256803443967583  3256803456568863
5   3256804273010958  3256804374631137  3256803448034929  3256803852328051
6   3256804288091339  3256804390450457  3256803613454020  3256804288946512
7   3256804340338295  3256804419670610  3256803636531347  3256804345871208
8   3256804374631137  3256804465546586  3256803958419735  3256804389102849
9   3256804549567127  3256804536446371  3256804096886433  3256804398579682
10  3256804564507961  3256804549567127  3256804146965002  3256804399002172
11  3256804598834886  3256804603507576  3256804520151422  3256804456692695
12  3256804600087452  3256804635290857  3256804538602358  3256804548714244
13  3256804603507576  3256804676604636  3256804583276496  3256804558295955
14  3256804606583693  3256804696130563  3256804627451745  3256804564507961
15  3256804627451745  3256804698461319  3256804679939115  3256804588660403
16  3256804679939115  3256804706160135  3256804680467020  3256804602698717
17  3256804683170661  3256804710640068  3256804683170661  3256804622918647
18  3256804697787771  3256804718617801  3256804683702066  3256804704992185
19  3256804718617801  3256804728034603  3256804697787771  3256804705540267

# %%
# my_list = df.columns.values.tolist()
# my_list
