# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import requests
import csv
import json

# %% [markdown]
# ## Product IDs For Women's Shoes

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200216411"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()
json
# Out:
# {'code': 200,
#  'cost': 364,
#  'data': {'abVersion': '1',
#   'crawler': False,
#   'searchResult': {'mods': {'searchRapidFilters': {'content': [{'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'mall_tag_switch',
#          'switchTag': {'displayTagType': 'text', 'tagText': 'PLUS'},
#          'selectedValue': 'mall:true',
#          'selected': False},
#         {'switchType': 'free_shipping_switch',
#          'switchChosenTag': {'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'switchTag': {'displayTagType': 'text', 'tagText': 'Free Shipping'},
#          'selectedValue': 'freeshipping:true',
#          'selected': False}]}]},
#     'searchRefineFilters': {'content': [{'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'shpf_co',
#        'type': 'logistics',
#        'title': 'Ship From',
#        'tItemType': 'search_refine_logistics',
#        'content': [{'countryCode': 'US',
#          'countryName': 'United States',
#          'selected': False},
#         {'countryCode': 'TR', 'countryName': 'Turkey', 'selected': False},
#         {'countryCode': 'CN', 'countryName': 'China', 'selected': False}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': True,
#        'loadFilter': True,
#        'refineTiling': False,
#        'paramName': 'cid',
#        'type': 'category',
#        'title': 'Categories',
#        'tItemType': 'search_refine_category',
#        'content': [{'categoryEnName': 'Formal Shoes',
#          'categoryMultiName': 'Formal Shoes',
#          'leafCategory': True,
#          'categoryId': 200216411,
#          'selected': True}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'bids',
#        'type': 'brandWall',
#        'title': 'Brands',
#        'tItemType': 'search_refine_brandwall',
#        'content': [{'brandName': 'Yeinshaars',
#          'brandId': '658490794',
#          'brandLogo': '//ae01.alicdn.com/kf/S6ae12d6d41ae4b8695c8e3e6f193f1b6I.jpg'},
#         {'brandName': 'PUAMSS',
#          'brandId': '202615814',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg'},
#         {'brandName': 'DESAI',
#          'brandId': '201873835',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1AF65XnmWBKNjSZFBq6xxUFXaM.jpg'},
#         {'brandName': 'DEKABR',
#          'brandId': '201648854',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1c.otXwoQMeJjy0Fpq6ATxpXaP.jpg'},
#         {'brandName': 'ci’e',
#          'brandId': '201628817',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1a2C6NpXXXXaLXFXXq6xXFXXXO.jpg'},
#         {'brandName': 'Camel',
#          'brandId': '200659455',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1t6i_KVXXXXXlXpXXq6xXFXXXe.jpg'}]},
#       {'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'user_favorite_switch',
#          'switchChosenTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'switchTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'selectedValue': 'pop:true',
#          'selected': False}]},
#       {'minTips': 'Min.',
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'currencySymbol': 'US $',
#        'refineTiling': False,
#        'paramName': 'pr',
#        'maxTips': 'Max',
#        'type': 'priceRange',
#        'title': 'Price',
#        'tItemType': 'search_refine_pricerange',
#        'content': [{'startPrice': '11.06',
#          'priceRanges': '11.06-23.07',
#          'endPrice': '23.07',
#          'boughtRate': 'Chosen by32%',
#          'selected': False},
#         {'startPrice': '23.07',
#          'priceRanges': '23.07-56.9',
#          'endPrice': '56.9',
#          'boughtRate': 'Chosen by33%',
#          'selected': False},
#         {'startPrice': '56.9',
#          'priceRanges': '56.9-87.98',
#          'endPrice': '87.98',
#          'boughtRate': 'Chosen by25%',
#          'selected': False}],
#        'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False},
#       {'paramType': 'List',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'attr',
#        'type': 'attribute',
#        'title': 'Attribute',
#        'tItemType': 'search_refine_attribute',
#        'content': [{'attributeId': 200000124,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 100010487,
#            'attributeValueName': '44'},
#           {'attributeValueId': 100010482, 'attributeValueName': '37'},
#           {'attributeValueId': 100010483, 'attributeValueName': '41'},
#           {'attributeValueId': 100010488, 'attributeValueName': '49'},
#           {'attributeValueId': 1583, 'attributeValueName': '10'},
#           {'attributeValueId': 100010420, 'attributeValueName': '11'},
#           {'attributeValueId': 3434, 'attributeValueName': '7'},
#           {'attributeValueId': 1663, 'attributeValueName': '12'},
#           {'attributeValueId': 153, 'attributeValueName': '4'},
#           {'attributeValueId': 100016232, 'attributeValueName': '42.5'},
#           {'attributeValueId': 100013888, 'attributeValueName': '40'}],
#          'attributeName': 'Shoe Size'},
#         {'attributeId': 14,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 193,
#            'attributeValueName': 'Black'},
#           {'attributeValueId': 201496390, 'attributeValueName': 'Rosy Red'},
#           {'attributeValueId': 10, 'attributeValueName': 'Red'},
#           {'attributeValueId': 100018786, 'attributeValueName': 'Clear'},
#           {'attributeValueId': 200003699, 'attributeValueName': 'MULTI'},
#           {'attributeValueId': 1052, 'attributeValueName': 'Pink'},
#           {'attributeValueId': 29, 'attributeValueName': 'White'},
#           {'attributeValueId': 200141872, 'attributeValueName': 'Deep Purple'},
#           {'attributeValueId': 1254, 'attributeValueName': 'Sky blue'},
#           {'attributeValueId': 1063, 'attributeValueName': 'Navy Blue'},
#           {'attributeValueId': 200000195, 'attributeValueName': 'Chocolate'},
#           {'attributeValueId': 173, 'attributeValueName': 'Blue'},
#           {'attributeValueId': 175, 'attributeValueName': 'Green'},
#           {'attributeValueId': 496, 'attributeValueName': 'purple'},
#           {'attributeValueId': 200004890, 'attributeValueName': 'dark grey'},
#           {'attributeValueId': 691, 'attributeValueName': 'Gray'},
#           {'attributeValueId': 200001438, 'attributeValueName': 'Khaki'}],
#          'attributeName': 'Color'},
#         {'attributeId': 20698,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002406,
#            'attributeValueName': 'Synthetic'},
#           {'attributeValueId': 529, 'attributeValueName': 'Canvas'},
#           {'attributeValueId': 1042, 'attributeValueName': 'Genuine Leather'},
#           {'attributeValueId': 200002431,
#            'attributeValueName': 'Stretch Fabric'},
#           {'attributeValueId': 200002429,
#            'attributeValueName': 'Mesh (Air mesh)'},
#           {'attributeValueId': 200002428, 'attributeValueName': 'Hemp'},
#           {'attributeValueId': 365211, 'attributeValueName': 'Cotton Fabric'},
#           {'attributeValueId': 439, 'attributeValueName': 'PVC'},
#           {'attributeValueId': 569, 'attributeValueName': 'Down'},
#           {'attributeValueId': 571, 'attributeValueName': 'microfiber'},
#           {'attributeValueId': 452, 'attributeValueName': 'PU'},
#           {'attributeValueId': 200004384,
#            'attributeValueName': 'Sequined Cloth'},
#           {'attributeValueId': 200001597,
#            'attributeValueName': 'Patent Leather'},
#           {'attributeValueId': 200004382, 'attributeValueName': 'flock'},
#           {'attributeValueId': 200004375, 'attributeValueName': 'Denim'}],
#          'attributeName': 'Upper Material'},
#         {'attributeId': 200198261,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200000908,
#            'attributeValueName': 'Basic',
#            'attributeImageUrl': '//ae01.alicdn.com/kf/HTB14y1FIpXXXXbuXVXX760XFXXX5.png'},
#           {'attributeValueId': 201440949, 'attributeValueName': 'Derby Shoes'},
#           {'attributeValueId': 201440950,
#            'attributeValueName': 'Brogue Shoes'},
#           {'attributeValueId': 4605, 'attributeValueName': 'Oxfords'},
#           {'attributeValueId': 200002452, 'attributeValueName': 'Loafers'}],
#          'attributeName': 'Shoes Type'},
#         {'attributeId': 200000485,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002425,
#            'attributeValueName': 'Square Toe'},
#           {'attributeValueId': 200002424, 'attributeValueName': 'Round Toe'},
#           {'attributeValueId': 200002423,
#            'attributeValueName': 'Pointed Toe'}],
#          'attributeName': 'Toe Shape'},
#         {'attributeId': 200000388,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002379,
#            'attributeValueName': 'Hook & Loop'},
#           {'attributeValueId': 200002378,
#            'attributeValueName': 'Elastic band'},
#           {'attributeValueId': 200002488, 'attributeValueName': 'Slip-On'},
#           {'attributeValueId': 200002383, 'attributeValueName': 'ZIP'},
#           {'attributeValueId': 1639, 'attributeValueName': 'Button'},
#           {'attributeValueId': 366093, 'attributeValueName': 'Lace-up'},
#           {'attributeValueId': 366092, 'attributeValueName': 'Buckle Strap'}],
#          'attributeName': 'Closure Type'},
#         {'attributeId': 20700,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 452,
#            'attributeValueName': 'PU'},
#           {'attributeValueId': 395, 'attributeValueName': 'EVA'},
#           {'attributeValueId': 201532816, 'attributeValueName': 'Hemp'},
#           {'attributeValueId': 202135826, 'attributeValueName': 'Shearling'},
#           {'attributeValueId': 484, 'attributeValueName': 'Fabric'},
#           {'attributeValueId': 366113, 'attributeValueName': 'Pigskin'},
#           {'attributeValueId': 869, 'attributeValueName': 'Latex'},
#           {'attributeValueId': 366115, 'attributeValueName': 'Sheepskin'},
#           {'attributeValueId': 202139808, 'attributeValueName': 'Plush'},
#           {'attributeValueId': 202139809, 'attributeValueName': 'Short Plush'},
#           {'attributeValueId': 202139810, 'attributeValueName': 'Pig Split'},
#           {'attributeValueId': 2929, 'attributeValueName': 'TPR'},
#           {'attributeValueId': 200002394,
#            'attributeValueName': 'Bonded Leather'},
#           {'attributeValueId': 200004376, 'attributeValueName': 'Cow Split'},
#           {'attributeValueId': 439, 'attributeValueName': 'PVC'},
#           {'attributeValueId': 123, 'attributeValueName': 'Rubber'},
#           {'attributeValueId': 200004374,
#            'attributeValueName': 'Full Grain Leather'}],
#          'attributeName': 'Insole Material'},
#         {'attributeId': 200001158,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 201447488,
#            'attributeValueName': 'Short Plush'},
#           {'attributeValueId': 202135823, 'attributeValueName': 'Cow Suede'},
#           {'attributeValueId': 452, 'attributeValueName': 'PU'},
#           {'attributeValueId': 100006333, 'attributeValueName': 'Neoprene'},
#           {'attributeValueId': 200002403,
#            'attributeValueName': 'Stretch & Spandex'},
#           {'attributeValueId': 524, 'attributeValueName': 'Velvet'},
#           {'attributeValueId': 100006073, 'attributeValueName': 'Mesh'},
#           {'attributeValueId': 200002406, 'attributeValueName': 'Synthetic'},
#           {'attributeValueId': 362122, 'attributeValueName': 'Plush'},
#           {'attributeValueId': 529, 'attributeValueName': 'Canvas'},
#           {'attributeValueId': 1042, 'attributeValueName': 'Genuine Leather'},
#           {'attributeValueId': 202135825, 'attributeValueName': 'Pig Suede'},
#           {'attributeValueId': 365211, 'attributeValueName': 'Cotton Fabric'},
#           {'attributeValueId': 202135826, 'attributeValueName': 'Shearling'},
#           {'attributeValueId': 366114, 'attributeValueName': 'Polyester'},
#           {'attributeValueId': 202115813, 'attributeValueName': 'Fleeces'},
#           {'attributeValueId': 202115814, 'attributeValueName': 'NONE'},
#           {'attributeValueId': 200005956,
#            'attributeValueName': 'Poly Propylene (PP)'},
#           {'attributeValueId': 439, 'attributeValueName': 'PVC'},
#           {'attributeValueId': 63, 'attributeValueName': 'nylon'}],
#          'attributeName': 'Lining Material'},
#         {'attributeId': 200001154,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002409,
#            'attributeValueName': 'vibram'},
#           {'attributeValueId': 200002408, 'attributeValueName': 'Cow Muscle'},
#           {'attributeValueId': 395, 'attributeValueName': 'EVA'},
#           {'attributeValueId': 1042, 'attributeValueName': 'Genuine Leather'},
#           {'attributeValueId': 100006946, 'attributeValueName': 'Cork'},
#           {'attributeValueId': 366040, 'attributeValueName': 'TPU'},
#           {'attributeValueId': 9000, 'attributeValueName': 'PU'},
#           {'attributeValueId': 2929, 'attributeValueName': 'TPR'},
#           {'attributeValueId': 200002394,
#            'attributeValueName': 'Bonded Leather'},
#           {'attributeValueId': 202191806, 'attributeValueName': 'TR'},
#           {'attributeValueId': 439, 'attributeValueName': 'PVC'},
#           {'attributeValueId': 361202, 'attributeValueName': 'Wood'},
#           {'attributeValueId': 123, 'attributeValueName': 'Rubber'},
#           {'attributeValueId': 124, 'attributeValueName': 'Plastic'}],
#          'attributeName': 'Outsole Material'}]}]},
#     'sortBar': {'tItemType': 'nt_mainsearch_sortbar',
#      'content': [{'sortOrders': [{'selected': True, 'order': 'default'}],
#        'sortType': 'default',
#        'sortMultiCopy': 'Best matches'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'orders',
#        'sortMultiCopy': 'Orders'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'price',
#        'sortMultiCopy': 'Price

#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $49.95',
#          'minPriceDiscount': 50,
#          'minPrice': 49.95,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030195356810'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Return'},
#          'dataSourceIds': '1000013764',
#          'sellingPointTagId': '1000013764'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S19f9bd2a4b8142f2a5a0bcd28d4aaa21H.jpg',
#         'imgWidth': 1669,
#         'imgHeight': 1600,
#         'imgType': '3'},
#        'itemType': 'productV3',
#        'productId': '3256804526166951',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': "SENBAO Fashion New Men's Dress Shoes Business Oxfords Designer Male Daily Shoes PU Leather Man Shoes 38-48",
#         'shortTitle': False,
#         'seoTitle': "SENBAO Fashion New Men's Dress Shoes Business Oxfords Designer Male Daily Shoes PU Leather Man Shoes 38-48"},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-09-03 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-9'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-9'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101e9d516686479578934069eb353%22%2C%22itemId%22%3A%223256804526166951%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030196592976%22%2C%22shipFrom%22%3A%22%22%2C%22order%22%3A%2243%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%224.03%22%7D',
#          'pdp_npi': '2%40dis%21USD%2118.68%2118.68%21%21%21%21%21%402101e9d516686479578934069eb353%2112000030196592976%21sea'},
# ...
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004689355949'}},
#        'trade': {'tradeDesc': '6 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $63.05',
#          'minPriceDiscount': 40,
#          'minPrice': 63.05,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030108590579'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#FD384F', 'position': '2'},
#           'displayTagType': 'text',
#           'tagText': 'Extra 1% off with coins'},
#          'source': 'flexiCoin',
#          'sellingPointTagId': 'm0000063'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': '//ae04.alicdn.com/kf/Se7c535be4385475e97542fbb14913bcbt.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'productId': '3256804177737633',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Men Loafers Coffee Suede Summer Walk Moccasins Slip On Women Flat Shoes Metal Lock Tassel Genuine Leather Causal Driving Shoes',
#         'shortTitle': False,
#         'seoTitle': 'Men Loafers Coffee Suede Summer Walk Moccasins Slip On Women Flat Shoes Metal Lock Tassel Genuine Leather Causal Driving Shoes'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-06-04 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359,m0000042',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-17'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-17'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101e9d516686479578934069eb353%22%2C%22itemId%22%3A%223256804177737633%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000028916335204%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2212%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%2284.21%22%7D',
#          'pdp_npi': '2%40dis%21USD%2191.98%2142.31%21%21%21%21%21%402101e9d516686479578934069eb353%2112000028916335204%21sea'},
#         'click': {'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $42.31',
#          'csp': '42.31,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.09774443507194519,
#          'sku_id': '12000028916335204',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'new_user_discount',
#          'oip': '91.98,0',
#          'selling_point': '885603359,m0000042',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004364052385'}},
#        'trade': {'tradeDesc': '12 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $42.31',
#          'minPriceDiscount': 54,
#          'minPrice': 42.31,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000028916335204'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $84.21'},
#          'sellingPointTagId': '885603359'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagImgWidth': 306,
#           'tagImgHeight': 64,
#           'tagStyle': {'color': '#FD384F', 'position': '1'},
#           'displayTagType': 'image',
#           'tagImgUrl': 'https://ae01.alicdn.com/kf/Sa92f8e896bbc423ea91aed7d4c2bbbd0g/306x64.png'},
#          'source': 'new_user_discount',
#          'sellingPointTagId': 'm0000042'}],
#        'productType': 'natural'},
#       {'lunchTime': '2022-10-11 00:00:00',
#        'image': {'imgUrl': 'https://ae04.alicdn.com/kf/Sf45e5fb5e1654a4c94828846188abd26F.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'session_id': '2022111617191714876948993883420003456022',
#          'selling_point': 'm0000064',
#          'aem_p4p_exposure': '1005004834300553',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e
#         'sessionId': '2022111617191714876948993883420003456022'},
#        'productType': 'ad'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S0e55cef0b0c8419cbbbce1b147d2f686X.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804394918228',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Size 45 Fashion PU Leather Men Dress Shoes Pointed Toe Bullock Oxfords Shoes For Men Slip On Designer Luxury Men Shoes',
#         'shortTitle': False,
#         'seoTitle': 'Size 45 Fashion PU Leather Men Dress Shoes Pointed Toe Bullock Oxfords Shoes For Men Slip On Designer Luxury Men Shoes'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-07-27 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000063,m0000042,m0000064',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-19'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'algo_exp_id': '123f46a3-5e8f-4c7d-acae-d95769118a8e-19'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%222101e9d516686479578934069eb353%22%2C%22itemId%22%3A%223256804394918228%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000029707282949%22%2C%22shipFrom%22%3A%22%22%2C%22order%22%3A%2213%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2133.2%2116.6%21%21%21%21%21%402101e9d516686479578934069eb353%2112000029707282949%21sea'},
#         'click': {'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $16.60',
#          'csp': '16.6,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.08586710691452026,
#          'sku_id': '12000029707282949',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'new_user_discount,flexiCoin',
#          'oip': '33.2,0',
#          'selling_point': 'm0000063,m0000042,m0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004581232980'}},
#        'trade': {'tradeDesc': '13 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $16.60',
#          'minPriceDiscount': 50,
#          'minPrice': 16.6,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000029707282949'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#FD384F', 'position': '2'},
#           'displayTagType': 'text',
#           'tagText': 'Extra 2% off with coins'},
#          'source': 'flexiCoin',
#          'sellingPointTagId': 'm0000063'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagImgWidth': 306,
#           'tagImgHeight': 64,
#           'tagStyle': {'color': '#FD384F', 'position': '1'},
#           'displayTagType': 'image',
#           'tagImgUrl': 'https://ae01.alicdn.com/kf/Sa92f8e896bbc423ea91aed7d4c2bbbd0g/306x64.png'},
#          'source': 'new_user_discount',
#          'sellingPointTagId': 'm0000042'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'}]}},
#    '_cost': 349.004278,
#    'pvid': 'af8428b9-7fb6-48bf-a34c-b42cb6688073',
#    'pageInfo': {'textTitle': 'All filters ',
#     'enableRefineRefactor2': False,
#     'textReset': 'Reset',
#     'textMore': 'See more ',
#     'pageSize': 20,
#     'finished': False,
#     'marketingPeriod': 'daily_period',
#     'searchResultType': 'normal_result',
#     'displayStyle': 'gallery',
#     'filterSelected': False,
#     'totalResults': 13683,
#     'trace': {'translsateTrace': {},
#      'exposure': {},
#      'customPage': {'dis_cat_name': 'Formal Shoes',
#       'tpp_access_trace': '18539#69073#297875',
#       'tenant': 'global'},
#      'custom': {},
#      'detailPage': {},
#      'page': {'ab': '6|1|2|9|9|71|12|6|9|7|3|8|23|11|2|5|9|8|10|1|13|7|1|3',
#       'list_page_type': 'main',
#       'hyperspaceTraceId': '2101e9d516686479578934069eb353',
#       'p4pId': 'cc654065-fdf5-4e06-9f6f-426238cf3658',
#       'algo_pvid': '123f46a3-5e8f-4c7d-acae-d95769118a8e',
#       'isAffiliateTraffic': 'false',
#       'btsid': '2101e9d516686479578934069eb353',
#       'pid': '808_0000_0201',
#       'gdpr': '2',
#       'trafficChannel': 'main',
#       'engine': 'ALI',
#       'aem_count': '13683',
#       'tenant': 'CN_CB',
#       'aem_ab': '6|1|2|9|9|71|12|6|9|7|3|8|23|11|2|5|9|8|10|1|13|7|1|3'},
#      'click': {},
#      'utLogMap': {'bizScene': 'mainSearch',
#       'filter_by': '{"categoryId":"200216411"}',
#       'no_result_tips_pos': 'null',
#       'language': 'en',
#       'sort_by': 'default_default',
#       'newSummaryCouponService': 'true',
#       'tpp_buckets': '687#2842#8090#10_687#2854#8148#9_687#4280#19688#1_687#5661#26522#7_687#2166#37192#23_687#2224#18951#1_687#3277#7904403#3_687#2172#5554#8_687#2158#5498#71_687#2163#5563#6_687#2701#7499#9_687#5275#24247#2_687#4837#22323#2_687#2167#5619#3_687#2724#7609#8_687#10162#437639#9_687#3860#17565#9_687#2168#6630#11_687#2497#26880#12_687#7205#34803#13_687#2352#16922#2_687#11988#445777#2_687#11987#445766#1_687#2164#5578#5_687#11744#443786#6_687#2165#5588#7_687#18539#297875#69073',
#       'user_tags': '-29883,NEWUSER',
#       'trafficChannel': 'main',
#       'query_from': 'direct',
#       'pageIndex': '1',
#       'hitDocs': 13683,
#       'traffic_diff_id': 'default',
#       'currency': 'USD'}},
#     'enableFilterOnlyRefine': False,
#     'textSearching': 'Searching...',
#     'selectedFilterCount': 1,
#     'textTotalResults': 'Show 10,000+ results ',
#     'success': True,
#     'page': 1,
#     'allResult': 'All results '},
#    'modsStyle': {'image': {'big_gap': '8', 'small_gap': '2'},
#     'prices': {'decimal_point': '.',
#      'comma_style': ',',
#      'symbol_position': 'left'}},
#    '_host': 'hippo.033001226170.us44',
#    'scm': '1007.28539.297875.0',
#    'version': 1.0,
#    'srpResult': [20],
#    'tpp_trace': '2101e9d516686479578934069eb353'},
#   'trafficChannel': 'main'},
#  'success': True}

# %%
## We want 'productID', 'title':'displayTitle', 'prices':'salePrice':'formattedPrice', 'evaluation':'starRating'

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)
# Out:
# 'code,cost,data,success\r\n200,364,1,True\r\n200,364,False,True\r\n200,364,"{\'mods\': {\'searchRapidFilters\': {\'content\': [{\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'mall_tag_switch\', \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'PLUS\'}, \'selectedValue\': \'mall:true\', \'selected\': False}, {\'switchType\': \'free_shipping_switch\', \'switchChosenTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'selectedValue\': \'freeshipping:true\', \'selected\': False}]}]}, \'searchRefineFilters\': {\'content\': [{\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': False, \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'shpf_co\', \'type\': \'logistics\', \'title\': \'Ship From\', \'tItemType\': \'search_refine_logistics\', \'content\': [{\'countryCode\': \'US\', \'countryName\': \'United States\', \'selected\': False}, {\'countryCode\': \'TR\', \'countryName\': \'Turkey\', \'selected\': False}, {\'countryCode\': \'CN\', \'countryName\': \'China\', \'selected\': False}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': True, \'loadFilter\': True, \'refineTiling\': False, \'paramName\': \'cid\', \'type\': \'category\', \'title\': \'Categories\', \'tItemType\': \'search_refine_category\', \'content\': [{\'categoryEnName\': \'Formal Shoes\', \'categoryMultiName\': \'Formal Shoes\', \'leafCategory\': True, \'categoryId\': 200216411, \'selected\': True}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'bids\', \'type\': \'brandWall\', \'title\': \'Brands\', \'tItemType\': \'search_refine_brandwall\', \'content\': [{\'brandName\': \'Yeinshaars\', \'brandId\': \'658490794\', \'brandLogo\': \'//ae01.alicdn.com/kf/S6ae12d6d41ae4b8695c8e3e6f193f1b6I.jpg\'}, {\'brandName\': \'PUAMSS\', \'brandId\': \'202615814\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg\'}, {\'brandName\': \'DESAI\', \'brandId\': \'201873835\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1AF65XnmWBKNjSZFBq6xxUFXaM.jpg\'}, {\'brandName\': \'DEKABR\', \'brandId\': \'201648854\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1c.otXwoQMeJjy0Fpq6ATxpXaP.jpg\'}, {\'brandName\': \'ci’e\', \'brandId\': \'201628817\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1a2C6NpXXXXaLXFXXq6xXFXXXO.jpg\'}, {\'brandName\': \'Camel\', \'brandId\': \'200659455\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1t6i_KVXXXXXlXpXXq6xXFXXXe.jpg\'}]}, {\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'user_favorite_switch\', \'switchChosenTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'switchTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'selectedValue\': \'pop:true\', \'selected\': False}]}, {\'minTips\': \'Min.\', \'existSelectedValue\': False, \'loadFilter\': False, \'currencySymbol\': \'US $\', \'refineTiling\': False, \'paramName\':  ...

# %%
compression_opts = dict(method='zip',
...                         archive_name='out.csv')  
>>> df.to_csv('out.zip', index=False,
...           compression=compression_opts)

# %%
from pathlib import Path  
>>> filepath = Path('out.csv')  
>>> filepath.parent.mkdir(parents=True, exist_ok=True)  
>>> df.to_csv(filepath)

# %%
# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   364     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'image': {'imgUrl': 'https://ae04.alicdn.com...  ...
#
#    data.searchResult.modsStyle.image.small_gap  \
# 0                                            2
#
#   data.searchResult.modsStyle.prices.decimal_point  \
# 0                                                .
#
#   data.searchResult.modsStyle.prices.comma_style  \
# 0                                              ,
#
#    data.searchResult.modsStyle.prices.symbol_position  \
# 0                                               left
#
#    data.searchResult._host data.searchResult.scm  data.searchResult.version  \
# 0  hippo.033001226170.us44   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  2101e9d516686479578934069eb353
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 72 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]
df
# Out:
#              data.searchResult.mods.itemList.content
# 0  [{'image': {'imgUrl': 'https://ae04.alicdn.com...

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['title']))
# Out:
# {'displayTitle': 'New 2022 Casual Orthopedics Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Shoes', 'shortTitle': False, 'seoTitle': 'New 2022 Casual Orthopedics Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Shoes'}

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

productId = ((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))
title = ((df["data.searchResult.mods.itemList.content"].values[0][0]['title']))

productId_list = []
title_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)
# Out:
# 3256803852328051
# ['3256803852328051', '3256803380552863', '3256804653685341', '3256803486771092', '2255800246726923', '3256804523348854', '3256803358999849', '3256803381222059', '3256804525848948', '3256804526166951', '3256804653529907', '3256802740060352', '3256804177703058', '3256804296418092', '3256803894028402', '3256802155306975', '3256804503041197', '3256804177737633', '3256804647985801', '3256804394918228']

# %%
for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)
# Out:
# ['New 2022 Casual Orthopedics Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Shoes', '2022 Casual Orthopedics Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Shoes', 'Fashion Casual Men Luxury Dress Shoe Genuine Leather Round Head Slip On Formal Wedding Tassel Loafers Men Black Man Oxford Shoes', '2022 Fashion Orthopedics Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Casual Shoes', 'Autumn Winter Crocodile Pattern Designer Men Dress Shoes Formal Office Business Luxury Brand Italian Style Black Brown Derbi', 'Plus Size Leather Shoes for Men Luxury Business Mens Dress Shoes Comfortable Casual Wedding Shoe Male Footewar Zapatos De Hombre', '2021 New Arrival Men Classic Business Formal Shoes leather shoes Men Lace-up oxford shoes', 'XIHAHA 2022 Casual Air Cushion Wide Feet Swollen Shoes Thumb Eversion Adjusting Soft Comfortable Diabetic Shoes Walking Shoes', "Loafers flat bottom cashmere leather tread soft comfortable shoes British style beanie men's shoes tide", "SENBAO Fashion New Men's Dress Shoes Business Oxfords Designer Male Daily Shoes PU Leather Man Shoes 38-48", 'Men Oxfords Genuine Leather Dress Shoes Brogue Office Casual Shoe Wedding Pointed Toe Black Brown Formal Men Loafers Luxury', "Formal Kid Suede Men Flat Shoes Khaki Real Leather Flat Penny Shoes Men's Driving Shoes Lazy Loafers Summer Walk Shoes for Men", 'Open Walk Shoes Suede Women Flat Shoes High Top Men Loafers Soft sole Slip On Causal Moccasins Genuine Leather Winter Ankle Boot', 'Manual customization style. High-end business leather shoes for men. Real cowhide leather shoes. High-quality cowhide is custom-', "2022 new small leather shoes flat low-top PU small black shoes casual men's shoes dress shoes men loafers for men black shoes", 'Men Dress Shoes Carved Falt Casual Shoes Man Leather Soft Bottom Lace Up Male Borgue Shoes Nonslip Outdoor Light Chaussure Homme', 'Uncle Saviano Loafers Men Shoes Suede Fashion Party Designer Italian Man Shoe Leather Daily Handmade Shoes for Men Original', 'Men Loafers Coffee Suede Summer Walk Moccasins Slip On Women Flat Shoes Metal Lock Tassel Genuine Leather Causal Driving Shoes', 'Oxford Leather Men Shoes Pointed Toe Genuine Leather Lace Up Brogues Formal Shoe Wedding Business Black Wine Red Dress Shoes Men', 'Size 45 Fashion PU Leather Men Dress Shoes Pointed Toe Bullock Oxfords Shoes For Men Slip On Designer Luxury Men Shoes']

# %%
price_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)
# Out:
# ['US $31.99', 'US $31.99', 'US $90.16', 'US $31.99', 'US $28.88', 'US $16.04', 'US $56.99', 'US $31.99', 'US $49.95', 'US $18.68', 'US $91.07', 'US $62.40', 'US $67.61', 'US $43.20', 'US $5.49', 'US $25.75', 'US $63.05', 'US $42.31', 'US $90.79', 'US $16.60']

# %%
star_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['sellingPoints']['evaluation']['starRating']))
    star_list.append(each_value)
    
print(star_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38516\584271995.py in <module>
#       2
#       3 for i in range (20):
# ----> 4     each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['sellingPoints']['evaluation']['starRating']))
#       5     star_list.append(each_value)
#       6
#
# TypeError: list indices must be integers or slices, not str

# %%
## Create dataframe with women's shoes product ids, titles, prices, and star ratings.

# %% [markdown]
# ## Product IDs For Women's Boots

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200216407"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out1.csv')  
df.to_csv('out1.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out1.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out1.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
wboots_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
wboots_productIds

# %% [markdown]
# ## Product IDs For Women's Flats

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200002155"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
wflats_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
wflats_productIds

# %% [markdown]
# ## Product IDs For Men's Shoes

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/100001615"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.searchResult.mods.itemList.content']]
df

# %%
print((df["data.searchResult.mods.itemList.content"].values[0][0]['productId']))

# %%
mshoes_productIds = {
    df["data.searchResult.mods.itemList.content"].values[0][0]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][1]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][2]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][3]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][4]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][5]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][6]['productId'], 
    df["data.searchResult.mods.itemList.content"].values[0][7]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][8]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][9]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][10]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][11]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][12]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][13]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][14]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][15]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][16]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][17]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][18]['productId'],
    df["data.searchResult.mods.itemList.content"].values[0][19]['productId'],
   
}
mshoes_productIds

# %% [markdown]
# ## Combine All Categories

# %%
data = np.array([[3256802423567155,
 3256803147612333,
 3256803313822268,
 3256803613454020,
 3256804146039143,
 3256804273010958,
 3256804288091339,
 3256804340338295,
 3256804374631137,
 3256804549567127,
 3256804564507961,
 3256804598834886,
 3256804600087452,
 3256804603507576,
 3256804606583693,
 3256804627451745,
 3256804679939115,
 3256804683170661,
 3256804697787771,
 3256804718617801], 
[3256803899670216,
 3256803910990175,
 3256804274369718,
 3256804288091339,
 3256804339852643,
 3256804374631137,
 3256804390450457,
 3256804419670610,
 3256804465546586,
 3256804536446371,
 3256804549567127,
 3256804603507576,
 3256804635290857,
 3256804676604636,
 3256804696130563,
 3256804698461319,
 3256804706160135,
 3256804710640068,
 3256804718617801,
 3256804728034603],
[3256802423567155,
 3256803290146743,
 3256803298586233,
 3256803305179821,
 3256803443967583,
 3256803448034929,
 3256803613454020,
 3256803636531347,
 3256803958419735,
 3256804096886433,
 3256804146965002,
 3256804520151422,
 3256804538602358,
 3256804583276496,
 3256804627451745,
 3256804679939115,
 3256804680467020,
 3256804683170661,
 3256804683702066,
 3256804697787771],
[2255800565385191,
 3256803193913624,
 3256803288474366,
 3256803380552863,
 3256803456568863,
 3256803852328051,
 3256804288946512,
 3256804345871208,
 3256804389102849,
 3256804398579682,
 3256804399002172,
 3256804456692695,
 3256804548714244,
 3256804558295955,
 3256804564507961,
 3256804588660403,
 3256804602698717,
 3256804622918647,
 3256804704992185,
 3256804705540267]])

dataset = pd.DataFrame({'Womens Shoes': data[0], 'Womens Boots': data[1], 'Women Flats': data[2], 'Mens Shoes': data[3]})
print(dataset)

# %%
df = pd.DataFrame(dataset)
df

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='productIds_bycategory.csv')  
df.to_csv('productIds_bycategory.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('productIds_bycategory.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)

# %% [markdown]
# ## Creating Product Feedback Database
# ### Plug in product IDs to compile and compare feedback within and between categories
# #### Keys to compare: "data.evaViewList.[0].buyerFeedback",  "data.evaViewList.[0].images", "data.productEvaluationStatistic."

# %%
url = "https://ali-express1.p.rapidapi.com/product/3256802423567155/feedback/"

querystring = {"country":"us","page":"1","type":"all"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.evaViewList',
'data.productEvaluationStatistic.evarageStar',
'data.productEvaluationStatistic.evarageStarRage',
'data.productEvaluationStatistic.fiveStarNum',
'data.productEvaluationStatistic.fiveStarRate',
'data.productEvaluationStatistic.fourStarNum',
'data.productEvaluationStatistic.fourStarRate',
'data.productEvaluationStatistic.negativeNum',
'data.productEvaluationStatistic.negativeRate',
'data.productEvaluationStatistic.neutralNum',
'data.productEvaluationStatistic.neutralRate',
'data.productEvaluationStatistic.oneStarNum',
'data.productEvaluationStatistic.oneStarRate',
'data.productEvaluationStatistic.positiveNum',
'data.productEvaluationStatistic.positiveRate',
'data.productEvaluationStatistic.threeStarNum',
'data.productEvaluationStatistic.threeStarRate',
'data.productEvaluationStatistic.totalNum',
'data.productEvaluationStatistic.twoStarNum',
'data.productEvaluationStatistic.twoStarRate',]]
        
df

# %%
print((df["data.evaViewList"].values[0][0]['buyerFeedback']))

# %%
print((df["data.evaViewList"].values[0][0]['images']))

# %% [markdown]
# ### Ended up pasting feedback results per product id into csv files for each category

# %%
# df.to_excel("output.xlsx",
#              sheet_name='Sheet_name_1')

# %% [markdown]
#  ## Product IDs

# %%
 
    Womens Shoes      Womens Boots       Women Flats        Mens Shoes
0   3256802423567155  3256803899670216  3256802423567155  2255800565385191
1   3256803147612333  3256803910990175  3256803290146743  3256803193913624
2   3256803313822268  3256804274369718  3256803298586233  3256803288474366
3   3256803613454020  3256804288091339  3256803305179821  3256803380552863
4   3256804146039143  3256804339852643  3256803443967583  3256803456568863
5   3256804273010958  3256804374631137  3256803448034929  3256803852328051
6   3256804288091339  3256804390450457  3256803613454020  3256804288946512
7   3256804340338295  3256804419670610  3256803636531347  3256804345871208
8   3256804374631137  3256804465546586  3256803958419735  3256804389102849
9   3256804549567127  3256804536446371  3256804096886433  3256804398579682
10  3256804564507961  3256804549567127  3256804146965002  3256804399002172
11  3256804598834886  3256804603507576  3256804520151422  3256804456692695
12  3256804600087452  3256804635290857  3256804538602358  3256804548714244
13  3256804603507576  3256804676604636  3256804583276496  3256804558295955
14  3256804606583693  3256804696130563  3256804627451745  3256804564507961
15  3256804627451745  3256804698461319  3256804679939115  3256804588660403
16  3256804679939115  3256804706160135  3256804680467020  3256804602698717
17  3256804683170661  3256804710640068  3256804683170661  3256804622918647
18  3256804697787771  3256804718617801  3256804683702066  3256804704992185
19  3256804718617801  3256804728034603  3256804697787771  3256804705540267

# %%
# my_list = df.columns.values.tolist()
# my_list
