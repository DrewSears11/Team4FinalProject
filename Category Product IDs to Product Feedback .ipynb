# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import requests
import csv
import json

# %% [markdown]
# ## Product IDs For Women's Shoes

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/100001606"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

json
# Out:
# {'code': 200,
#  'cost': 619,
#  'data': {'abVersion': '1',
#   'crawler': False,
#   'searchResult': {'mods': {'searchRapidFilters': {'content': [{'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'mall_tag_switch',
#          'switchTag': {'displayTagType': 'text', 'tagText': 'PLUS'},
#          'selectedValue': 'mall:true',
#          'selected': False},
#         {'switchType': 'free_shipping_switch',
#          'switchChosenTag': {'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'switchTag': {'displayTagType': 'text', 'tagText': 'Free Shipping'},
#          'selectedValue': 'freeshipping:true',
#          'selected': False}]}]},
#     'searchRefineFilters': {'content': [{'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'shpf_co',
#        'type': 'logistics',
#        'title': 'Ship From',
#        'tItemType': 'search_refine_logistics',
#        'content': [{'countryCode': 'US',
#          'countryName': 'United States',
#          'selected': False},
#         {'countryCode': 'TR', 'countryName': 'Turkey', 'selected': False},
#         {'countryCode': 'CN', 'countryName': 'China', 'selected': False}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False,
#        'existSelectedValue': True,
#        'loadFilter': True,
#        'refineTiling': False,
#        'paramName': 'cid',
#        'type': 'category',
#        'title': 'Categories',
#        'tItemType': 'search_refine_category',
#        'content': [{'categoryEnName': "Women's Shoes",
#          'categoryMultiName': "Women's Shoes",
#          'leafCategory': False,
#          'categoryId': 100001606,
#          'selected': True}]},
#       {'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'bids',
#        'type': 'brandWall',
#        'title': 'Brands',
#        'tItemType': 'search_refine_brandwall',
#        'content': [{'brandName': 'QYCKABY',
#          'brandId': '201465587',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1RwZQn8DH8KJjSspnq6zNAVXab.jpg'},
#         {'brandName': 'BeauToday',
#          'brandId': '201465854',
#          'brandLogo': '//ae01.alicdn.com/kf/Sd329a849ab5b4b778b4be655047e50d8L.png'},
#         {'brandName': 'DoraTasia',
#          'brandId': '201689863',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1lR_.elfM8KJjSZPiq6xdspXaA.jpg'},
#         {'brandName': 'PUAMSS',
#          'brandId': '202615814',
#          'brandLogo': '//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg'}]},
#       {'paramType': 'List',
#        'rapidTiling': True,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'selectedSwitches',
#        'type': 'featureSwitch',
#        'title': 'Special Services & Ratings',
#        'tItemType': 'search_refine_feature_switch',
#        'content': [{'switchType': 'user_favorite_switch',
#          'switchChosenTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'switchTag': {'tagImgWidth': 64,
#           'tagImgHeight': 12,
#           'displayTagType': 'image_text',
#           'tagText': '& Up',
#           'tagImgUrl': '//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png'},
#          'selectedValue': 'pop:true',
#          'selected': False}]},
#       {'minTips': 'Min.',
#        'existSelectedValue': False,
#        'loadFilter': False,
#        'currencySymbol': 'US $',
#        'refineTiling': False,
#        'paramName': 'pr',
#        'maxTips': 'Max',
#        'type': 'priceRange',
#        'title': 'Price',
#        'tItemType': 'search_refine_pricerange',
#        'content': [{'startPrice': '7.25',
#          'priceRanges': '7.25-13.67',
#          'endPrice': '13.67',
#          'boughtRate': 'Chosen by35%',
#          'selected': False},
#         {'startPrice': '13.67',
#          'priceRanges': '13.67-37.37',
#          'endPrice': '37.37',
#          'boughtRate': 'Chosen by40%',
#          'selected': False},
#         {'startPrice': '37.37',
#          'priceRanges': '37.37-76.64',
#          'endPrice': '76.64',
#          'boughtRate': 'Chosen by11%',
#          'selected': False}],
#        'paramType': 'String',
#        'rapidTiling': False,
#        'isMulti': False},
#       {'paramType': 'List',
#        'rapidTiling': False,
#        'isMulti': True,
#        'existSelectedValue': False,
#        'multiValSep': ',',
#        'loadFilter': False,
#        'refineTiling': False,
#        'paramName': 'attr',
#        'type': 'attribute',
#        'title': 'Attribute',
#        'tItemType': 'search_refine_attribute',
#        'content': [{'attributeId': 200000124,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 100010487,
#            'attributeValueName': '44'},
#           {'attributeValueId': 100010483, 'attributeValueName': '41'},
#           {'attributeValueId': 1583, 'attributeValueName': '10'},
#           {'attributeValueId': 100010420, 'attributeValueName': '11'},
#           {'attributeValueId': 100010386, 'attributeValueName': '19'},
#           {'attributeValueId': 100010384, 'attributeValueName': '17'},
#           {'attributeValueId': 100010385, 'attributeValueName': '18'},
#           {'attributeValueId': 1394, 'attributeValueName': '6'},
#           {'attributeValueId': 1663, 'attributeValueName': '12'},
#           {'attributeValueId': 153, 'attributeValueName': '4'}],
#          'attributeName': 'Shoe Size'},
#         {'attributeId': 14,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 193,
#            'attributeValueName': 'Black'},
#           {'attributeValueId': 200002984, 'attributeValueName': 'Burgundy'},
#           {'attributeValueId': 201496390, 'attributeValueName': 'Rosy Red'},
#           {'attributeValueId': 201302648, 'attributeValueName': 'rose'},
#           {'attributeValueId': 100018786, 'attributeValueName': 'Clear'},
#           {'attributeValueId': 200003699, 'attributeValueName': 'MULTI'},
#           {'attributeValueId': 1052, 'attributeValueName': 'Pink'},
#           {'attributeValueId': 29, 'attributeValueName': 'White'},
#           {'attributeValueId': 200141872, 'attributeValueName': 'Deep Purple'},
#           {'attributeValueId': 1254, 'attributeValueName': 'Sky blue'},
#           {'attributeValueId': 173, 'attributeValueName': 'Blue'},
#           {'attributeValueId': 200004870, 'attributeValueName': 'Deep Blue'},
#           {'attributeValueId': 175, 'attributeValueName': 'Green'},
#           {'attributeValueId': 496, 'attributeValueName': 'purple'},
#           {'attributeValueId': 200004891, 'attributeValueName': 'Lavender'},
#           {'attributeValueId': 200004890, 'attributeValueName': 'dark grey'},
#           {'attributeValueId': 691, 'attributeValueName': 'Gray'},
#           {'attributeValueId': 200001438, 'attributeValueName': 'Khaki'},
#           {'attributeValueId': 200002130, 'attributeValueName': 'Ivory'}],
#          'attributeName': 'Color'},
#         {'attributeId': 20698,
#          'displayType': 'normal',
#          'attributeValues': [{'attributeValueId': 200002429,
#            'attributeValueName': 'Mesh (Air mesh)'},
#           {'attributeValueId': 365601, 'attributeValueName': 'Lace'},
#           {'attributeValueId': 365230, 'attributeValueName': 'Silk'},
#           {'attributeValueId': 571, 'attributeValueName': 'microfiber'},
#           {'attributeValueId': 63, 'attributeValueName': 'nylon'},
#           {'attributeValueId': 452, 'attributeValueName': 'PU'},
#           {'attributeValueId': 200004384,
#            'attributeValueName': 'Sequined Cloth'},
#           {'attributeValueId': 200001597,
#            'attributeValueName': 'Patent Leather'},
#           {'attributeValueId': 1886, 'attributeValueName': 'Corduroy'},
#           {'attributeValueId': 200004382, 'attributeValueName': 'flock'},
#           {'attributeValueId': 200004381, 'attributeValueName': 'Cloth'},
#           {'attributeValueId': 123, 'attributeValueName': 'Rubber'}],
#          'attributeName': 'Upper Material'}]}]},
#     'sortBar': {'tItemType': 'nt_mainsearch_sortbar',
#      'content': [{'sortOrders': [{'selected': True, 'order': 'default'}],
#        'sortType': 'default',
#        'sortMultiCopy': 'Best matches'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'orders',
#        'sortMultiCopy': 'Orders'},
#       {'sortOrders': [{'selected': False, 'order': 'desc'}],
#        'sortType': 'price',
#        'sortMultiCopy': 'Price (High to Low)'},
#       {'sortOrders': [{'selected': False, 'order': 'asc'}],
#        'sortType': 'price',
#        'sortMultiCopy': 'Price (Low to High)'}]},
#     'itemList': {'content': [{'image': {'imgUrl': 'https://ae04.alicdn.com/kf/Sd99361f918464457a9e1a998ab3fb780z.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256803290146743',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX',
#         'shortTitle': False,
#         'seoTitle': '2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2021-10-28 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-0'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-0'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256803290146743%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000025961149058%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22111%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2144.35%2135.48%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000025961149058%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $35.48',
#          'csp': '35.48,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.10270771384239197,
#          'sku_id': '12000025961149058',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '44.35,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003476461495'}},
#        'trade': {'tradeDesc': '111 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $35.48',
#          'minPriceDiscount': 20,
#          'minPrice': 35.48,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000025961149058'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': '//ae04.alicdn.com/kf/Sc7b2aa3e2e144d8d945d405a27fbcc2bw.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'productId': '3256804146039143',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers',
#         'shortTitle': False,
#         'seoTitle': 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 4.9,
#         'starHeight': 48},
#        'lunchTime': '2022-06-01 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-1'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-1'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804146039143%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000028888819519%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22589%22%2C%22star%22%3A%224.9%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%218.75%218.75%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000028888819519%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $8.75',
#          'csp': '8.75,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.1450834572315216,
#          'sku_id': '12000028888819519',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'oip': '8.75,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004332353895'}},
#        'trade': {'tradeDesc': '589 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $8.75',
#          'minPrice': 8.75,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 1,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000028888819519'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': '//ae04.alicdn.com/kf/Se2fdb0c9d5984d1cbafda986715d136cN.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'productId': '3256802759707769',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2022 Summer Women Fashion Personality Indoor Home bathroom Massage Bubble Slide Men Lady Outdoor Beach Thick Sole Bubble Slipper',
#         'shortTitle': False,
#         'seoTitle': '2022 Summer Women Fashion Personality Indoor Home bathroom Massage Bubble Slide Men Lady Outdoor Beach Thick Sole Bubble Slipper'},
#        'p4p': {'clickUrl': '//us-click.aliexpress.com/ci_bb?ot=hippo-033003024170.us68&a=1012770678&e=UbVJ1VW0qV3b0S1eey7xiiwta-k0m9JY33M0DpLeiwzV.RSqk21wzPv0uPI7z8A8UVo9qsSvJbTwoqYllG8lClrfVZTpD.C427lsY.OvoKlsUeu9d7N0yInG1GWsxpkPL6yyuRZoobbXs0H-pgFy0Ou9-wSx7LbUPxoDWIVip8G7sea0B7tDPTWNt35SOsFlRQBmOwLqdNfLzfB.OhlXJL58iiKcVXnhcbF8pFXJaWShYtlXPxRxa0Asxf65jLrTHVvw04e9DnWPOYgdeTP95u7ekVBdCbtj7gHFptVSqYxBoM.UBpsACe9q5KAsegDXMt3LAS.4lHG6qLdNz2nGV90Oq42PnE-GYXvEgNxiwymx9LVCXbNEXKwl5pDszSUidMMUKzPQdwmTE0LLxKZN0pQVkWH7F0JAZ0Ul5kx0xHhhAA9k75ppagITZF4.B1MITX0gpId35wbnpmqJ3qr7kOyQEZYcHxTfyuV8tPOcQEnFK2gROV6aMjT5vOaIoUoPZV9lytOStOO89MCCdwSWpGkIfcSVuY8ze8fIHDUVfl45Pb8MURkTAd2gw4kJqsTbcr373AWIFXm2KPDNmeS9eKBn91VwBodKWWAJKJnWOGUaZU7wCkqGbXN6JMarbORqarVJMgMoKWY-lWFbJeBYbBOLM.9IXfKPFXiqcmN1SJFjwbdHtnHKCtkV5cj2uQr0GBB-XjuEcJHuDoCV31mhnALCnKMnhp6nqNrHxJT8GoLAah47VUW1k6V5Q7L1z48qmMN.AVzLiA5sSBBi2UycBFT9uQbcgBL0088oKNV.qD2Q9hU.hMg9XggAIbSkZPsdYV4xGlnE.3R.7yXDWNKXjSnWTIG57jRo4fZMJTnMeG.xIvF3Fpxh33M4WYAiOQ2802F9m0TGI1UWCTyjrFi5bWo5Ua7m81aI&ap=1&rp=1',
#         'adTag': {'tagStyle': {'backgroundColor': 'rgba(0,0,0,0.20)'},
#          'displayTagType': 'text',
#          'tagText': 'AD'},
#         'sessionId': '20221117182013367869953669970001582854'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 4.7,
#         'starHeight': 48},
#        'lunchTime': '2021-07-06 00:00:00',
#        'trace': {'exposure': {'session_id': '20221117182013367869953669970001582854',
#          'selling_point': '885603359',
#          'aem_p4p_exposure': '1005002946022521',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-2'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_detail': '20221117182013367869953669970001582854',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-2'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256802759707769%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000023791257499%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%221186%22%2C%22star%22%3A%224.7%22%2C%22shippingFee%22%3A%226.44%22%7D',
#          'pdp_npi': '2%40dis%21USD%2110.78%216.9%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000023791257499%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_click': '1005002946022521',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $6.90',
#          'csp': '6.9,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'session_id': '20221117182013367869953669970001582854',
#          'sku_id': '12000023791257499',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '10.78,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005002946022521'}},
#        'trade': {'tradeDesc': '1186 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $6.90',
#          'minPriceDiscount': 36,
#          'minPrice': 6.9,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000023791257499'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $6.44'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'ad'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/H491b858e12e647a59a24771052261924Z.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256803411670824',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Daddy shoes female Breathable Versatile Sports shoes Student  Non-slip Lncreased and Thin Fashion Lady shoe Comfort Reflection',
#         'shortTitle': False,
#         'seoTitle': 'Daddy shoes female Breathable Versatile Sports shoes Student  Non-slip Lncreased and Thin Fashion Lady shoe Comfort Reflection'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2021-11-24 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359,m0000063',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-3'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-3'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256803411670824%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000026451088726%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2274%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%222.53%22%7D',
#          'pdp_npi': '2%40dis%21USD%2116.5%2116.5%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000026451088726%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $16.50',
#          'csp': '16.5,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.1568000614643097,
#          'sku_id': '12000026451088726',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'flexiCoin',
#          'oip': '16.5,0',
#          'selling_point': '885603359,m0000063',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003597985576'}},
#        'trade': {'tradeDesc': '74 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $16.50',
#          'minPrice': 16.5,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 1,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000026451088726'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $2.53'},
#          'sellingPointTagId': '885603359'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#FD384F', 'position': '2'},
#           'displayTagType': 'text',
#           'tagText': 'Extra 2% off with coins'},
#          'source': 'flexiCoin',
#          'sellingPointTagId': 'm0000063'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S2027b9c07ef64da5aa864ef3e6bac6340.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804697787771',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002',
#         'shortTitle': False,
#         'seoTitle': '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-10-25 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-4'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-4'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804697787771%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030883733807%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22469%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2174.99%2166.74%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030883733807%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $66.74',
#          'csp': '66.74,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.16734039783477783,
#          'sku_id': '12000030883733807',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '74.99,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004884102523'}},
#        'trade': {'tradeDesc': '469 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $66.74',
#          'minPriceDiscount': 11,
#          'minPrice': 66.74,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030883733807'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/H73ba04960e04419f9995e776ec4a43db0.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256803305179821',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': "2021 Spring new leisure one-word solid color beach slippers indoor drag fashion women's shoes SU02",
#         'shortTitle': False,
#         'seoTitle': "2021 Spring new leisure one-word solid color beach slippers indoor drag fashion women's shoes SU02"},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 4.9,
#         'starHeight': 48},
#        'lunchTime': '2021-11-01 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-5'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-5'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256803305179821%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000026034922718%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2273%22%2C%22star%22%3A%224.9%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2120.56%2119.53%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000026034922718%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $19.53',
#          'csp': '19.53,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.12656354904174805,
#          'sku_id': '12000026034922718',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '20.56,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003491494573'}},
#        'trade': {'tradeDesc': '73 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $19.53',
#          'minPriceDiscount': 5,
#          'minPrice': 19.53,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000026034922718'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S561cb363a7a34a778677ae729d37ef2cN.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804568740738',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes',
#         'shortTitle': False,
#         'seoTitle': 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-09-16 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-6'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-6'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804568740738%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030348977606%22%2C%22shipFrom%22%3A%22%22%2C%22order%22%3A%22262%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2119.98%219.99%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030348977606%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $9.99',
#          'csp': '9.99,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.2243039608001709,
#          'sku_id': '12000030348977606',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[86884]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '19.98,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004755055490'}},
#        'trade': {'tradeDesc': '262 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $9.99',
#          'minPriceDiscount': 50,
#          'minPrice': 9.99,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030348977606'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S2389a7b42e3e4857bbac3de672028c46s.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256803298586233',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Canvas shoes for children 2020 cloth shoes for boys and girls, sportswear shoesUG-51',
#         'shortTitle': False,
#         'seoTitle': 'Canvas shoes for children 2020 cloth shoes for boys and girls, sportswear shoesUG-51'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2021-10-30 00:00:00',
#        'trace': {'exposure': {'selling_point': '885603359',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-7'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-7'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256803298586233%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000026001401975%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22145%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.16%22%7D',
#          'pdp_npi': '2%40dis%21USD%2124.92%2123.42%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000026001401975%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $23.42',
#          'csp': '23.42,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.11975955963134766,
#          'sku_id': '12000026001401975',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '24.92,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005003484900985'}},
#        'trade': {'tradeDesc': '145 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $23.42',
#          'minPriceDiscount': 6,
#          'minPrice': 23.42,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000026001401975'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.16'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/S95d1b6252b0748b2ad2fe5a32756845e7.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804629958195',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Winter Woman Flannel Slippers Couple Indoor Non-Slip Slipper 2022 Man Fluff Slides Warm Plush Bedroom Lady Polar Fleece Shoes',
#         'shortTitle': False,
#         'seoTitle': 'Winter Woman Flannel Slippers Couple Indoor Non-Slip Slipper 2022 Man Fluff Slides Warm Plush Bedroom Lady Polar Fleece Shoes'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 4.7,
#         'starHeight': 48},
#        'lunchTime': '2022-10-06 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-8'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-8'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804629958195%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030598127737%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22422%22%2C%22star%22%3A%224.7%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2119.85%218.54%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030598127737%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $8.54',
#          'csp': '8.54,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.13916471600532532,
#          'sku_id': '12000030598127737',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '19.85,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004816272947'}},
#        'trade': {'tradeDesc': '422 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $8.54',
#          'minPriceDiscount': 57,
#          'minPrice': 8.54,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030598127737'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'lunchTime': '2022-10-31 00:00:00',
#        'image': {'imgUrl': '//ae04.alicdn.com/kf/Seaf59e027751445ebdd94c4f102e85977.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'trace': {'exposure': {'selling_point': 'm0000042,m0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-9'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-9'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804718617801%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030969137554%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22553%22%2C%22star%22%3A%22%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%21143.36%2153.04%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030969137554%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $53.04',
#          'csp': '53.04,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.2397308051586151,
#          'sku_id': '12000030969137554',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'new_user_discount',
#          'oip': '143.36,0',
#          'selling_point': 'm0000042,m0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004904932553'}},
#        'trade': {'tradeDesc': '553 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'productId': '3256804718617801',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini',
#         'shortTitle': False,
#         'seoTitle': '2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini'},
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $53.04',
#          'minPriceDiscount': 63,
#          'minPrice': 53.04,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030969137554'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagImgWidth': 306,
#           'tagImgHeight': 64,
#           'tagStyle': {'color': '#FD384F', 'position': '1'},
#           'displayTagType': 'image',
#           'tagImgUrl': 'https://ae01.alicdn.com/kf/Sa92f8e896bbc423ea91aed7d4c2bbbd0g/306x64.png'},
#          'source': 'new_user_discount',
#          'sellingPointTagId': 'm0000042'},
#         {'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/Sf082b546bf6543ce86520b022dd7d35dA.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804731069436',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': "2023 Sheepskin Wool Comprehensive Anti-skid Snow Boots Women's Mini Short Boots Warm Winter Thickened Women's Shoes Botas Mujer",
#         'shortTitle': False,
#         'seoTitle': "2023 Sheepskin Wool Comprehensive Anti-skid Snow Boots Women's Mini Short Boots Warm Winter Thickened Women's Shoes Botas Mujer"},
#        'p4p': {'clickUrl': '//us-click.aliexpress.com/ci_bb?ot=hippo-033003024170.us68&a=1012770678&e=IMAwP-siNVTb0S1eey7xiiwta-k0m9JY33M0DpLeiwzV.RSqk21wzPv0uPI7z8A8UVo9qsSvJbTMS0ep--e2cf1leQi4CUuhOGsNmxq1whuaxZ-Q9kbhw5JaRrOzHn6tLlvg4iNlrt94wDCjETwVYmc4XfaO6ZOL4dZHbkNKrZ5yG2M41DlSrmBTa58d4j-juZJvIlyv.HacgjxeMwFD3iac.E.Mw2OaYfoVEiJBXVYIPj7PmLtqU53BjUC8dMgSjzmIHXkz.ebu3pFQXQm7Y-4BxabVUqmMQaDP1AabAAnvauSgLHoA1zLdywEv-JRxuqi3Tc9pxlfdDquNj5xPhmF7xIDcYsMpsfS1Ql2zRFysJeaQ7M0lInTDFCsz0HcJkxNCy8SmTdKUFZFh-xdCQGdFJeZMdMR4YQAPZO-aaWq8vtOo7yQcqPL0oqcvtVVF.SY4TM4p8CxJRCpIKDPyzayf4D6tK0Cl6GSyiOJ5pwZF8Blf8QAxl4Cg1XTvZ31TDtYIyh7oAgDh7hurBgQ7g1bHcYLXzc4U2fJzktTsXGjB0ax0pzpZsznUvfkbX3dCjiTIMLn.H-xzvcEjgh9voIjvvc7HGmnkaqHv21do6LhzkmbzQrPEvEmHoO2akIiOthcQ4MN9rkUz4hfAeYNfJ4C0CSXSGkHnwNHE2y.Fp9qzYT3SYDBgsyL04m67nVdYCQlcviQjBohtLaMlXo88DQiQzFn7gyqqCu2VhK-Ky12QRT1LmL8Ovh.SNmEz7-BU7K9beP-L7i7JVtK27F4..CC0NQ-XyXAKIIDDPHT1xdpZJVm7VqoBh4n2rszsj19G14NVff7HuOCQHjfCioDkFcWUV5.y0OG4wktq4BuHvuiLWW1Oc60opA__&ap=2&rp=2',
#         'adTag': {'tagStyle': {'backgroundColor': 'rgba(0,0,0,0.20)'},
#          'displayTagType': 'text',
#          'tagText': 'AD'},
#         'sessionId': '20221117182013367869953669970001582854'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-11-03 00:00:00',
#        'trace': {'exposure': {'session_id': '20221117182013367869953669970001582854',
#          'selling_point': '885603359',
#          'aem_p4p_exposure': '1005004917384188',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-10'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_detail': '20221117182013367869953669970001582854',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-10'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804731069436%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000031009973489%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2224%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%2210.96%22%7D',
#          'pdp_npi': '2%40dis%21USD%2113.7%218.9%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000031009973489%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_click': '1005004917384188',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $8.90',
#          'csp': '8.9,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'session_id': '20221117182013367869953669970001582854',
#          'sku_id': '12000031009973489',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '13.7,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004917384188'}},
#        'trade': {'tradeDesc': '24 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $8.90',
#          'minPriceDiscount': 35,
#          'minPrice': 8.9,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000031009973489'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $10.96'},
#          'sellingPointTagId': '885603359'}],
# ...
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-16'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-16'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804652978019%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030693268291%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%2243%22%2C%22star%22%3A%225.0%22%2C%22shippingFee%22%3A%223.96%22%7D',
#          'pdp_npi': '2%40dis%21USD%2113.2%216.6%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030693268291%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $6.60',
#          'csp': '6.6,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.20515194535255432,
#          'sku_id': '12000030693268291',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '13.2,0',
#          'selling_point': '885603359',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004839292771'}},
#        'trade': {'tradeDesc': '43 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $6.60',
#          'minPriceDiscount': 50,
#          'minPrice': 6.6,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030693268291'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': '+ Shipping: US $3.96'},
#          'sellingPointTagId': '885603359'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': '//ae04.alicdn.com/kf/Sceb09cc17df84ff7ac10bb1f7c6bdd0dr.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'productId': '3256804728034603',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': 'Waterproof Boots Women Winter 2022 Non-slip Winter Snow Boots Platform Shoes Warm Ankle Boots Women Cotton Shoes Bottine Femme',
#         'shortTitle': False,
#         'seoTitle': 'Waterproof Boots Women Winter 2022 Non-slip Winter Snow Boots Platform Shoes Warm Ankle Boots Women Cotton Shoes Bottine Femme'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-11-02 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-17'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-17'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804728034603%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000031001321020%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22122%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%218.7%214.35%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000031001321020%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $4.35',
#          'csp': '4.35,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.204356849193573,
#          'sku_id': '12000031001321020',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '8.7,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004914349355'}},
#        'trade': {'tradeDesc': '122 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $4.35',
#          'minPriceDiscount': 50,
#          'minPrice': 4.35,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000031001321020'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'},
#       {'image': {'imgUrl': '//ae04.alicdn.com/kf/S828f1fe96414499ebc92be11dd7e7bb7x.jpg',
#         'imgWidth': 750,
#         'imgHeight': 1000,
#         'imgType': '1'},
#        'itemType': 'productV3',
#        'productId': '3256804720448303',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2022 Winter New Women Boots Mid Heel Thermal Genuine Leather Chelsea Plush Thicken Wool Cotton Snow  Booties Rubber Short Shoes',
#         'shortTitle': False,
#         'seoTitle': '2022 Winter New Women Boots Mid Heel Thermal Genuine Leather Chelsea Plush Thicken Wool Cotton Snow  Booties Rubber Short Shoes'},
#        'p4p': {'clickUrl': '//us-click.aliexpress.com/ci_bb?ot=hippo-033003024170.us68&a=1012770678&e=EoxZuqWn-3Db0S1eey7xiiwta-k0m9JY33M0DpLeiwzV.RSqk21wzPv0uPI7z8A8UVo9qsSvJbROvwoyYE9AgF2ZIazgPS8q7XHQLJEtr7180qvoToeg4JJaRrOzHn6tLlvg4iNlrt94wDCjETwVYmc4XfaO6ZOL4dZHbkNKrZ58Qk.rehce9NbC-YJP2WmaeZ1NDGnlAk0wVVrX6qz9rVTry9dchkHArIOTgutkwAZ3lMxD8xRfF2czc4Fe-XY2gzeKffuyt82ywaHgpwXjNMHvap4LAO-a8Cp-vBiq8MoyPZh0vvWp-bMC9RE9cm6jm3ZA9otZjVgAr5yeoiUM4INbAfbIDm1.viq-6KWwEyizc9UKK2CKp-conJRDhaJ6zKNFhFpPFlprvviLQGki4cibJ5NG0K7nO40rvG-LWD.E9gNndsLawLGsRAX.eZA.YftA5RqQmN.y9CCCKGwxlMrlfLTznEBJ-3mAyw0wWqrWON1t-afe9msN9eeV6cPuKAX4mUS0gH5cCK9IK-dWjSL.qxgIV5-D8Mw48QmZkebjuDFP.MED00vdaVuCFHni9qIVx9-bALL.59IYkfuG.p8Mfcn9SSMSoIjEK41-zDn8aojv0LzPguSNgxOgMuuEZrXxPScGCTXFhljtFDPtEE-Dit5ExJiPK4MD4iGRiz01l3Vhu5X8c.yx6pOMdkvqeWUs7skBmG3oRzXW7TJQkQDImWD.Z0XSjuQSzTOW-fMxi4bSiUgsDammzV.pwlNPCpYt5HR9-4GjuCJzU0goQknw0B-Ma9cjNEQhnH.-5QcPy3AQGCDRTgJCET23oInnQS1JIxAQDJD0nBKNvVlF0RQJrYAdyb4jH-4Ma5fr3ugThVC0PE3JGS1brmv.f.9FXvcuWDzCwE5O.L8n2AJcDDnGvIQ2XcY-&ap=3&rp=3',
#         'adTag': {'tagStyle': {'backgroundColor': 'rgba(0,0,0,0.20)'},
#          'displayTagType': 'text',
#          'tagText': 'AD'},
#         'sessionId': '20221117182013367869953669970001582854'},
#        'lunchTime': '2022-10-31 00:00:00',
#        'trace': {'exposure': {'session_id': '20221117182013367869953669970001582854',
#          'selling_point': 'm0000064',
#          'aem_p4p_exposure': '1005004906763055',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-18'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_detail': '20221117182013367869953669970001582854',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-18'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804720448303%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000030976379326%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%224%22%2C%22star%22%3A%22%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2179.0%2147.4%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000030976379326%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'aem_p4p_click': '1005004906763055',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $47.40',
#          'csp': '47.4,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'session_id': '20221117182013367869953669970001582854',
#          'sku_id': '12000030976379326',
#          'mixrank_success': 'false',
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '79.0,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004906763055'}},
#        'trade': {'tradeDesc': '4 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $47.40',
#          'minPriceDiscount': 40,
#          'minPrice': 47.4,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000030976379326'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'ad'},
#       {'image': {'imgUrl': 'https://ae04.alicdn.com/kf/Sb595c0e94ee34751acc75810524369fdR.jpg',
#         'imgWidth': 800,
#         'imgHeight': 800,
#         'imgType': '11'},
#        'itemType': 'productV3',
#        'productId': '3256804428351342',
#        'itemCardType': 'manhattan',
#        'title': {'displayTitle': '2022 the new leisure shoes lazy flat shoes',
#         'shortTitle': False,
#         'seoTitle': '2022 the new leisure shoes lazy flat shoes'},
#        'evaluation': {'starWidth': 48,
#         'starUrl': 'https://ae01.alicdn.com/kf/S567d6bf538214abf95c1e5825c7e6a05t/48x48.png',
#         'starRating': 5.0,
#         'starHeight': 48},
#        'lunchTime': '2022-08-05 00:00:00',
#        'trace': {'exposure': {'selling_point': 'm0000064',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-19'},
#         'custom': {},
#         'detailPage': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'algo_exp_id': '28b493a1-e72d-43ef-b45e-b52006594839-19'},
#         'pdpParams': {'pdp_cdi': '%7B%22traceId%22%3A%22210318cf16687380130726126e16cf%22%2C%22itemId%22%3A%223256804428351342%22%2C%22fromPage%22%3A%22search%22%2C%22skuId%22%3A%2212000029838336842%22%2C%22shipFrom%22%3A%22CN%22%2C%22order%22%3A%22193%22%2C%22star%22%3A%225.0%22%2C%22freeShip%22%3A%22true%22%7D',
#          'pdp_npi': '2%40dis%21USD%2133.89%2130.16%21%21%21%21%21%40210318cf16687380130726126e16cf%2112000029838336842%21sea'},
#         'click': {'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'haveSellingPoint': 'true'},
#         'utLogMap': {'original_price_type': 'offer',
#          'formatted_price': 'US $30.16',
#          'csp': '30.16,1',
#          'x_object_type': 'productV3',
#          'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#          'hit_19_forbidden': False,
#          'is_detail_next': '1',
#          'model_ctr': 0.07914742827415466,
#          'sku_id': '12000029838336842',
#          'mixrank_success': 'false',
#          'custom_group': 1,
#          'sku_ic_tags': '[]',
#          'is_adult_certified': False,
#          'mixrank_enable': 'false',
#          'ump_atmospheres': 'none',
#          'oip': '33.89,0',
#          'selling_point': 'm0000064',
#          'original_price_strategy': 'sku_opt',
#          'x_object_id': '1005004614666094'}},
#        'trade': {'tradeDesc': '193 sold'},
#        'nativeCardType': 'nt_srp_cell_g',
#        'prices': {'builderType': 'skuCoupon',
#         'taxRate': '0',
#         'pricesStyle': 'default',
#         'salePrice': {'formattedPrice': 'US $30.16',
#          'minPriceDiscount': 11,
#          'minPrice': 30.16,
#          'priceType': 'sale_price',
#          'discount': -1,
#          'minPriceType': 2,
#          'currencyCode': 'USD'},
#         'prefix': 'Sale price:',
#         'currencySymbol': 'US $',
#         'skuId': '12000029838336842'},
#        'sellingPoints': [{'tagStyleType': 'default',
#          'tagContent': {'tagStyle': {'color': '#009966', 'position': '4'},
#           'displayTagType': 'text',
#           'tagText': 'Free Shipping'},
#          'sellingPointTagId': 'm0000064'}],
#        'productType': 'natural'}]}},
#    '_cost': 597.830086,
#    'pvid': '2b381bc0-139f-47f4-93ad-3b605c3d5fcf',
#    'pageInfo': {'textTitle': 'All filters ',
#     'enableRefineRefactor2': False,
#     'textReset': 'Reset',
#     'textMore': 'See more ',
#     'pageSize': 20,
#     'finished': False,
#     'marketingPeriod': 'daily_period',
#     'searchResultType': 'normal_result',
#     'displayStyle': 'gallery',
#     'filterSelected': False,
#     'totalResults': 469870,
#     'trace': {'translsateTrace': {},
#      'exposure': {},
#      'customPage': {'dis_cat_name': "Women's Shoes",
#       'tpp_access_trace': '18539#69073#297875',
#       'tenant': 'global'},
#      'custom': {},
#      'detailPage': {},
#      'page': {'ab': '4|4|1|9|2|71|3|1|11|8|1|10|26|11|2|2|5|5|3|1|5|7|7|2',
#       'list_page_type': 'main',
#       'hyperspaceTraceId': '210318cf16687380130726126e16cf',
#       'p4pId': '76d90daf-adee-4c7c-affe-20ad4807bb3a',
#       'algo_pvid': '28b493a1-e72d-43ef-b45e-b52006594839',
#       'isAffiliateTraffic': 'false',
#       'btsid': '210318cf16687380130726126e16cf',
#       'pid': '808_0000_0201',
#       'gdpr': '2',
#       'trafficChannel': 'main',
#       'engine': 'ALI',
#       'aem_count': '469870',
#       'tenant': 'CN_CB',
#       'aem_ab': '4|4|1|9|2|71|3|1|11|8|1|10|26|11|2|2|5|5|3|1|5|7|7|2'},
#      'click': {},
#      'utLogMap': {'bizScene': 'mainSearch',
#       'filter_by': '{"categoryId":"100001606"}',
#       'no_result_tips_pos': 'null',
#       'language': 'en',
#       'sort_by': 'default_default',
#       'newSummaryCouponService': 'true',
#       'tpp_buckets': '687#2842#8083#3_687#2854#8137#2_687#4280#19694#7_687#5661#26523#8_687#2166#37196#26_687#2224#18947#1_687#3277#7904402#2_687#2172#5556#10_687#13204#450549#19_687#2158#437757#71_687#2163#5558#1_687#2701#7495#5_687#5275#24246#1_687#4837#22323#2_687#2167#5615#1_687#2724#7606#5_687#10162#437639#9_687#3860#26849#11_687#2168#6630#11_687#2497#6790#3_687#7205#34795#5_687#2352#13813#2_687#11988#445776#1_687#11987#445769#4_687#2164#5575#2_687#11744#443782#4_687#2165#5588#7_687#18539#297875#69073',
#       'user_tags': '-29883,NEWUSER',
#       'trafficChannel': 'main',
#       'query_from': 'direct',
#       'pageIndex': '1',
#       'hitDocs': 469870,
#       'traffic_diff_id': 'default',
#       'currency': 'USD'}},
#     'enableFilterOnlyRefine': False,
#     'textSearching': 'Searching...',
#     'selectedFilterCount': 1,
#     'textTotalResults': 'Show 460,000+ results ',
#     'success': True,
#     'page': 1,
#     'allResult': 'All results '},
#    'modsStyle': {'image': {'big_gap': '8', 'small_gap': '2'},
#     'prices': {'decimal_point': '.',
#      'comma_style': ',',
#      'symbol_position': 'left'}},
#    '_host': 'hippo.033003024170.us68',
#    'scm': '1007.28539.297875.0',
#    'version': 1.0,
#    'srpResult': [20],
#    'tpp_trace': '210318cf16687380130726126e16cf'},
#   'trafficChannel': 'main'},
#  'success': True}

# %%
# test = []

# for i in range (5):
#     each_page = {"sort_type":"default","page":i,"page_size":"20","sort_order":"default"}
#     response = requests.request("GET", url, headers=headers, params=each_page)
#     json = response.json()
#     test.append(json)
#test

# %%
#We want 'productID', 'title':'displayTitle', 'prices':'salePrice':'formattedPrice', 'trade':'tradeDesc', 'evaluation':'starRating'

# %%
df = pd.DataFrame(json)
df
# Out:
#                 code  cost                                               data  \
# abVersion        200   619                                                  1
# crawler          200   619                                              False
# searchResult     200   619  {'mods': {'searchRapidFilters': {'content': [{...
# trafficChannel   200   619                                               main
#
#                 success
# abVersion          True
# crawler            True
# searchResult       True
# trafficChannel     True

# %%
df.to_csv(index=False)
# Out:
# 'code,cost,data,success\n200,619,1,True\n200,619,False,True\n200,619,"{\'mods\': {\'searchRapidFilters\': {\'content\': [{\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'mall_tag_switch\', \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'PLUS\'}, \'selectedValue\': \'mall:true\', \'selected\': False}, {\'switchType\': \'free_shipping_switch\', \'switchChosenTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'selectedValue\': \'freeshipping:true\', \'selected\': False}]}]}, \'searchRefineFilters\': {\'content\': [{\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': False, \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'shpf_co\', \'type\': \'logistics\', \'title\': \'Ship From\', \'tItemType\': \'search_refine_logistics\', \'content\': [{\'countryCode\': \'US\', \'countryName\': \'United States\', \'selected\': False}, {\'countryCode\': \'TR\', \'countryName\': \'Turkey\', \'selected\': False}, {\'countryCode\': \'CN\', \'countryName\': \'China\', \'selected\': False}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': True, \'loadFilter\': True, \'refineTiling\': False, \'paramName\': \'cid\', \'type\': \'category\', \'title\': \'Categories\', \'tItemType\': \'search_refine_category\', \'content\': [{\'categoryEnName\': ""Women\'s Shoes"", \'categoryMultiName\': ""Women\'s Shoes"", \'leafCategory\': False, \'categoryId\': 100001606, \'selected\': True}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'bids\', \'type\': \'brandWall\', \'title\': \'Brands\', \'tItemType\': \'search_refine_brandwall\', \'content\': [{\'brandName\': \'QYCKABY\', \'brandId\': \'201465587\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1RwZQn8DH8KJjSspnq6zNAVXab.jpg\'}, {\'brandName\': \'BeauToday\', \'brandId\': \'201465854\', \'brandLogo\': \'//ae01.alicdn.com/kf/Sd329a849ab5b4b778b4be655047e50d8L.png\'}, {\'brandName\': \'DoraTasia\', \'brandId\': \'201689863\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1lR_.elfM8KJjSZPiq6xdspXaA.jpg\'}, {\'brandName\': \'PUAMSS\', \'brandId\': \'202615814\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1W1oeaijrK1RjSsplq6xHmVXal.jpg\'}]}, {\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'user_favorite_switch\', \'switchChosenTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'switchTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'selectedValue\': \'pop:true\', \'selected\': False}]}, {\'minTips\': \'Min.\', \'existSelectedValue\': False, \'loadFilter\': False, \'currencySymbol\': \'US $\', \'refineTiling\': False, \'paramName\': \'pr\', \'maxTips\': \'Max\', \'type\': \'priceRange\', \'title\': \'Price\', \'tItemType\': \'search_refine_pricerange\', \'content\': [{\'startPrice\': \'7.25\', \'priceRanges\': \'7.25-13.67\', \'endPrice\': \'13.67\', \'boughtRate\': \'Chosen by35%\', \' ...

# %%
compression_opts = dict(method='zip',
...                         archive_name='out.csv')  
>>> df.to_csv('out.zip', index=False,
...           compression=compression_opts)

# %%
from pathlib import Path  
>>> filepath = Path('out.csv')  
>>> filepath.parent.mkdir(parents=True, exist_ok=True)  
>>> df.to_csv(filepath)

# %%
# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)

# %%
df = df[['data.searchResult.mods.itemList.content']]
#df.loc[0]

# %%
productId_list = []
title_list = []
price_list = []
sold_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['trade']['tradeDesc']))
    sold_list.append(each_value)
    
print(sold_list)
# Out:
# ['3256803290146743', '3256804146039143', '3256802759707769', '3256803411670824', '3256804697787771', '3256803305179821', '3256804568740738', '3256803298586233', '3256804629958195', '3256804718617801', '3256804731069436', '3256804655013583', '3256804450894638', '3256803313822268', '3256804139482283', '3256804606583693', '3256804652978019', '3256804728034603', '3256804720448303', '3256804428351342']
# ['2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX', 'Best Selling Smiley Face Ladies Warm Furry Home House Cute Bedroom Pantoufle Women  Men Slippers', '2022 Summer Women Fashion Personality Indoor Home bathroom Massage Bubble Slide Men Lady Outdoor Beach Thick Sole Bubble Slipper', 'Daddy shoes female Breathable Versatile Sports shoes Student  Non-slip Lncreased and Thin Fashion Lady shoe Comfort Reflection', '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002', "2021 Spring new leisure one-word solid color beach slippers indoor drag fashion women's shoes SU02", 'Bad Bunny Un Verano Sin Ti Autumn Winter Fulffy Fur Slippers Plush Fleece Flat Love Heart Slippers Indoor Slippers Couple Shoes', 'Canvas shoes for children 2020 cloth shoes for boys and girls, sportswear shoesUG-51', 'Winter Woman Flannel Slippers Couple Indoor Non-Slip Slipper 2022 Man Fluff Slides Warm Plush Bedroom Lady Polar Fleece Shoes', '2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini', "2023 Sheepskin Wool Comprehensive Anti-skid Snow Boots Women's Mini Short Boots Warm Winter Thickened Women's Shoes Botas Mujer", 'Women Winter Luxury Fashion Cotton Bubble Slides Flat Platform Round Toe Warm Bubble Slippers Wholesale Bulk Women Shoes Big', 'YISHEN Unisex Summer Slides For Women Indoor Slippers Bubble Slides Massage Litchi Sandals Fashion Designer Sandals Men Clogs', 'NEW Winter Keep Warm Women Fur Furry Slippers for Home Fluffy Soft Indoor Slides Non Slip Indoor House Shoes', 'Man Women Shark Slippers Summer Home Anti-skid EVA Solid Color Couple Parents Kids Outdoor Cool Indoor Household Funny Shoes', 'Cute Animal Slipper For Women Girls Kawaii Fluffy Winter Warm Upgrate Slippers Woman Cartoon Milk Cow House Slippers Funny Shoes', 'Thick Bottom Home Shark Shape Cloud Slippers Adults Kids Non Slip Waterproof EVA Slides Children Winter Warm Funny Flip Flops', 'Waterproof Boots Women Winter 2022 Non-slip Winter Snow Boots Platform Shoes Warm Ankle Boots Women Cotton Shoes Bottine Femme', '2022 Winter New Women Boots Mid Heel Thermal Genuine Leather Chelsea Plush Thicken Wool Cotton Snow  Booties Rubber Short Shoes', '2022 the new leisure shoes lazy flat shoes']
# ['US $35.48', 'US $8.75', 'US $6.90', 'US $16.50', 'US $66.74', 'US $19.53', 'US $9.99', 'US $23.42', 'US $8.54', 'US $53.04', 'US $8.90', 'US $8.63', 'US $13.19', 'US $19.99', 'US $12.00', 'US $8.74', 'US $6.60', 'US $4.35', 'US $47.40', 'US $30.16']
# ['111 sold', '589 sold', '1186 sold', '74 sold', '469 sold', '73 sold', '262 sold', '145 sold', '422 sold', '553 sold', '24 sold', '56 sold', '197 sold', '348 sold', '514 sold', '440 sold', '43 sold', '122 sold', '4 sold', '193 sold']

# %%
print(len(productId_list), len(title_list), len(price_list), len(sold_list))
# Out:
# 20 20 20 20

# %%
columns = {'Product ID': productId_list, 'Title': title_list, 'Price': price_list, 'Number Sold': sold_list}
wshoes_df = pd.DataFrame(columns)
wshoes_df
# Out:
#           Product ID                                              Title  \
# 0   3256803290146743  2021 Wool wool slippers autumn and winter wome...
# 1   3256804146039143  Best Selling Smiley Face Ladies Warm Furry Hom...
# 2   3256802759707769  2022 Summer Women Fashion Personality Indoor H...
# 3   3256803411670824  Daddy shoes female Breathable Versatile Sports...
# 4   3256804697787771  2022 new large size linen slippers home couple...
# 5   3256803305179821  2021 Spring new leisure one-word solid color b...
# 6   3256804568740738  Bad Bunny Un Verano Sin Ti Autumn Winter Fulff...
# 7   3256803298586233  Canvas shoes for children 2020 cloth shoes for...
# 8   3256804629958195  Winter Woman Flannel Slippers Couple Indoor No...
# 9   3256804718617801  2022 Winter Boots Fur Ladies Snow Boots Real S...
# 10  3256804731069436  2023 Sheepskin Wool Comprehensive Anti-skid Sn...
# 11  3256804655013583  Women Winter Luxury Fashion Cotton Bubble Slid...
# 12  3256804450894638  YISHEN Unisex Summer Slides For Women Indoor S...
# 13  3256803313822268  NEW Winter Keep Warm Women Fur Furry Slippers ...
# 14  3256804139482283  Man Women Shark Slippers Summer Home Anti-skid...
# 15  3256804606583693  Cute Animal Slipper For Women Girls Kawaii Flu...
# 16  3256804652978019  Thick Bottom Home Shark Shape Cloud Slippers A...
# 17  3256804728034603  Waterproof Boots Women Winter 2022 Non-slip Wi...
# 18  3256804720448303  2022 Winter New Women Boots Mid Heel Thermal G...
# 19  3256804428351342         2022 the new leisure shoes lazy flat shoes
#
#         Price Number Sold
# 0   US $35.48    111 sold
# 1    US $8.75    589 sold
# 2    US $6.90   1186 sold
# 3   US $16.50     74 sold
# 4   US $66.74    469 sold
# 5   US $19.53     73 sold
# 6    US $9.99    262 sold
# 7   US $23.42    145 sold
# 8    US $8.54    422 sold
# 9   US $53.04    553 sold
# 10   US $8.90     24 sold
# 11   US $8.63     56 sold
# 12  US $13.19    197 sold
# 13  US $19.99    348 sold
# 14  US $12.00    514 sold
# 15   US $8.74    440 sold
# 16   US $6.60     43 sold
# 17   US $4.35    122 sold
# 18  US $47.40      4 sold
# 19  US $30.16    193 sold

# %%
# star_list = []

# for i in range (20):
#     each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['sellingPoints']['evaluation']['starRating']))
#     star_list.append(each_value)
    
# print(star_list)

# %%
## Create dataframe with women's shoes product ids, titles, prices, number sold, and star ratings.

# %% [markdown]
# ## Product IDs For Women's Boots

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200216407"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)
# Out:
# 'code,cost,data,success\n200,612,1,True\n200,612,False,True\n200,612,"{\'mods\': {\'searchRapidFilters\': {\'content\': [{\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'mall_tag_switch\', \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'PLUS\'}, \'selectedValue\': \'mall:true\', \'selected\': False}, {\'switchType\': \'free_shipping_switch\', \'switchChosenTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'switchTag\': {\'displayTagType\': \'text\', \'tagText\': \'Free Shipping\'}, \'selectedValue\': \'freeshipping:true\', \'selected\': False}]}]}, \'searchRefineFilters\': {\'content\': [{\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': False, \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'shpf_co\', \'type\': \'logistics\', \'title\': \'Ship From\', \'tItemType\': \'search_refine_logistics\', \'content\': [{\'countryCode\': \'US\', \'countryName\': \'United States\', \'selected\': False}, {\'countryCode\': \'TR\', \'countryName\': \'Turkey\', \'selected\': False}, {\'countryCode\': \'CN\', \'countryName\': \'China\', \'selected\': False}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': False, \'existSelectedValue\': True, \'loadFilter\': True, \'refineTiling\': False, \'paramName\': \'cid\', \'type\': \'category\', \'title\': \'Categories\', \'tItemType\': \'search_refine_category\', \'content\': [{\'categoryEnName\': ""Women\'s Boots"", \'categoryMultiName\': ""Women\'s Boots"", \'leafCategory\': False, \'categoryId\': 200216407, \'selected\': True}]}, {\'paramType\': \'String\', \'rapidTiling\': False, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'bids\', \'type\': \'brandWall\', \'title\': \'Brands\', \'tItemType\': \'search_refine_brandwall\', \'content\': [{\'brandName\': \'BeauToday\', \'brandId\': \'201465854\', \'brandLogo\': \'//ae01.alicdn.com/kf/Sd329a849ab5b4b778b4be655047e50d8L.png\'}, {\'brandName\': \'MORAZORA\', \'brandId\': \'201605913\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1CYg6QFXXXXXAaXXX760XFXXX3.png\'}, {\'brandName\': \'DoraTasia\', \'brandId\': \'201689863\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1lR_.elfM8KJjSZPiq6xdspXaA.jpg\'}, {\'brandName\': \'krazing pot\', \'brandId\': \'202380086\', \'brandLogo\': \'//ae01.alicdn.com/kf/HTB1IFlejr_I8KJjy1Xaq6zsxpXaf.jpg\'}]}, {\'paramType\': \'List\', \'rapidTiling\': True, \'isMulti\': True, \'existSelectedValue\': False, \'multiValSep\': \',\', \'loadFilter\': False, \'refineTiling\': False, \'paramName\': \'selectedSwitches\', \'type\': \'featureSwitch\', \'title\': \'Special Services & Ratings\', \'tItemType\': \'search_refine_feature_switch\', \'content\': [{\'switchType\': \'user_favorite_switch\', \'switchChosenTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'switchTag\': {\'tagImgWidth\': 64, \'tagImgHeight\': 12, \'displayTagType\': \'image_text\', \'tagText\': \'& Up\', \'tagImgUrl\': \'//ae01.alicdn.com/kf/HTB1W4orR7voK1RjSZFw763iCFXal.png\'}, \'selectedValue\': \'pop:true\', \'selected\': False}]}, {\'minTips\': \'Min.\', \'existSelectedValue\': False, \'loadFilter\': False, \'currencySymbol\': \'US $\', \'refineTiling\': False, \'paramName\': \'pr\', \'maxTips\': \'Max\', \'type\': \'priceRange\', \'title\': \'Price\', \'tItemType\': \'search_refine_pricerange\', \'content\': [{\'startPrice\': \'10.81\', \'priceRanges\': \'10.81-16.6\', \'endPrice\': \'16.6\', \'boughtRate\': \'Chosen by36% ...

# %%
compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   612     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'lunchTime': '2022-10-31 00:00:00', 'image':...  ...
#
#    data.searchResult.modsStyle.image.small_gap  \
# 0                                            2
#
#   data.searchResult.modsStyle.prices.decimal_point  \
# 0                                                .
#
#   data.searchResult.modsStyle.prices.comma_style  \
# 0                                              ,
#
#    data.searchResult.modsStyle.prices.symbol_position  \
# 0                                               left
#
#    data.searchResult._host data.searchResult.scm  data.searchResult.version  \
# 0  hippo.033001226170.us44   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  210318be16687380142714437ea4b3
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 72 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]

# %%
productId_list = []
title_list = []
price_list = []
sold_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['trade']['tradeDesc']))
    sold_list.append(each_value)
    
print(sold_list)
# Out:
# ['3256804718617801', '3256804483026473', '3256804731069436', '3256804728034603', '3256804531066038', '3256804608934725', '3256804570453332', '3256804592642401', '3256804571739712', '3256804543268400', '3256804720448303', '3256804374631137', '3256803512234986', '3256804611897209', '3256804692665573', '3256804274369718', '3256804594023362', '3256804180023633', '3256804658270402', '3256804630865314']
# ['2022 Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots Super Mini', '2022 New Thick Plush Winter Keep Warm Boots for Women Non-slip Waterproof Snow Boots Woman Flat Heels Warm Cotton Padded Shoes', "2023 Sheepskin Wool Comprehensive Anti-skid Snow Boots Women's Mini Short Boots Warm Winter Thickened Women's Shoes Botas Mujer", 'Waterproof Boots Women Winter 2022 Non-slip Winter Snow Boots Platform Shoes Warm Ankle Boots Women Cotton Shoes Bottine Femme', 'Women Boots Slip On Winter Shoes For Women Waterproof Ankle Boots Winter Boots Female Snow Botines 2022 Black Botas Femininas', 'Leather Lace UP Large Size Women Boots Side Bag Women Ankle Boots Spring Autumn Shoes Woman Motorcycle Boots Punk Botas Mujer', 'New Snow Boot Style Short Mini Winter Sheepskin Boots Women Waterproof Natural Wool Ankle Boots Fur Lined Ankle Warm Flat Shoes', 'Snow Boots Plush Warm Ankle Boots For Women Winter Shoes Waterproof Boots Women Female Winter Shoes Booties Botas Mujer', "Ladies Casual Comfortable Simple Fashion 2023 New Students Short Boots Women's Ankle Boots Knit Socks Platform Women's Slip-ons", 'Autumn Flat Thick Sole Knee High Rain Boots Women Rubber Solid Color Waterproof Shoes Ladies All Match Knight Long Boots 2022', '2022 Winter New Women Boots Mid Heel Thermal Genuine Leather Chelsea Plush Thicken Wool Cotton Snow  Booties Rubber Short Shoes', "Gnazhee 2022 Women's Knee-high Boots Black White Pointed Toe Sexy Thin High Heels Party Shoes Ladies Stiletto Boots", 'BJ Shoes Lightweight Winter Shoes for Men Snow Boots for Women Waterproof Winter Footwear Slip on Unisex Ankle Winter Boots', 'Waterproof Winter Boots for Women 2022 New Faux Fur Long Plush Snow Boots Woman Platform Ankle Boots Warm Cotton Couples Shoes', 'Winter Boots Fur Ladies Snow Boots Real Sheepskin Wool Low-cut Warm Fur Shoes Man and Women Winter Short Boots', "Paris Station Fashion Women's Boots Pointed Toe High Heel Boots Sexy Motorcycle Boots Four Seasons Party Over Knee Boots", 'Women Boots Super Warm Snow Boots For Winter Shoes Women Waterproof Ankle Boots With Heels Casual Winter Botas Mujer 2022 New', 'Unisex Sock Aqua Shoes Skinners Swimming Sneakers Yoga Minimalist Beach Sports Barefoot Ultra Portable Lightweight Run Footwear', 'New Snow Boot Style Short Mini Winter Sheepskin Boots Women Waterproof Natural Wool Ankle Boots Fur Lined Ankle Warm Flat Shoes', 'New Winter Women Short Plush Warm Snow Boots Flats Casual Shoes Suede Fur Chelsea Ankle Boots Platform Ladies Shoes Botas Mujer']
# ['US $53.04', 'US $15.28', 'US $8.90', 'US $4.35', 'US $11.57', 'US $51.48', 'US $11.26', 'US $12.98', 'US $10.40', 'US $60.48', 'US $47.40', 'US $56.08', 'US $11.45', 'US $18.05', 'US $63.24', 'US $49.80', 'US $16.92', 'US $18.41', 'US $10.48', 'US $11.67']
# ['553 sold', '1175 sold', '24 sold', '122 sold', '1289 sold', '48 sold', '1933 sold', '849 sold', '36 sold', '46 sold', '4 sold', '76 sold', '144 sold', '649 sold', '39 sold', '142 sold', '302 sold', '196 sold', '348 sold', '1456 sold']

# %%
columns = {'Product ID': productId_list, 'Title': title_list, 'Price': price_list, 'Number Sold': sold_list}
wboots_df = pd.DataFrame(columns)
wboots_df
# Out:
#           Product ID                                              Title  \
# 0   3256804718617801  2022 Winter Boots Fur Ladies Snow Boots Real S...
# 1   3256804483026473  2022 New Thick Plush Winter Keep Warm Boots fo...
# 2   3256804731069436  2023 Sheepskin Wool Comprehensive Anti-skid Sn...
# 3   3256804728034603  Waterproof Boots Women Winter 2022 Non-slip Wi...
# 4   3256804531066038  Women Boots Slip On Winter Shoes For Women Wat...
# 5   3256804608934725  Leather Lace UP Large Size Women Boots Side Ba...
# 6   3256804570453332  New Snow Boot Style Short Mini Winter Sheepski...
# 7   3256804592642401  Snow Boots Plush Warm Ankle Boots For Women Wi...
# 8   3256804571739712  Ladies Casual Comfortable Simple Fashion 2023 ...
# 9   3256804543268400  Autumn Flat Thick Sole Knee High Rain Boots Wo...
# 10  3256804720448303  2022 Winter New Women Boots Mid Heel Thermal G...
# 11  3256804374631137  Gnazhee 2022 Women's Knee-high Boots Black Whi...
# 12  3256803512234986  BJ Shoes Lightweight Winter Shoes for Men Snow...
# 13  3256804611897209  Waterproof Winter Boots for Women 2022 New Fau...
# 14  3256804692665573  Winter Boots Fur Ladies Snow Boots Real Sheeps...
# 15  3256804274369718  Paris Station Fashion Women's Boots Pointed To...
# 16  3256804594023362  Women Boots Super Warm Snow Boots For Winter S...
# 17  3256804180023633  Unisex Sock Aqua Shoes Skinners Swimming Sneak...
# 18  3256804658270402  New Snow Boot Style Short Mini Winter Sheepski...
# 19  3256804630865314  New Winter Women Short Plush Warm Snow Boots F...
#
#         Price Number Sold
# 0   US $53.04    553 sold
# 1   US $15.28   1175 sold
# 2    US $8.90     24 sold
# 3    US $4.35    122 sold
# 4   US $11.57   1289 sold
# 5   US $51.48     48 sold
# 6   US $11.26   1933 sold
# 7   US $12.98    849 sold
# 8   US $10.40     36 sold
# 9   US $60.48     46 sold
# 10  US $47.40      4 sold
# 11  US $56.08     76 sold
# 12  US $11.45    144 sold
# 13  US $18.05    649 sold
# 14  US $63.24     39 sold
# 15  US $49.80    142 sold
# 16  US $16.92    302 sold
# 17  US $18.41    196 sold
# 18  US $10.48    348 sold
# 19  US $11.67   1456 sold

# %% [markdown]
# ## Product IDs For Women's Flats

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/200002155"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   429     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'image': {'imgUrl': 'https://ae04.alicdn.com...  ...
#
#    data.searchResult.modsStyle.image.small_gap  \
# 0                                            2
#
#   data.searchResult.modsStyle.prices.decimal_point  \
# 0                                                .
#
#   data.searchResult.modsStyle.prices.comma_style  \
# 0                                              ,
#
#    data.searchResult.modsStyle.prices.symbol_position  \
# 0                                               left
#
#    data.searchResult._host data.searchResult.scm  data.searchResult.version  \
# 0  hippo.033003006131.us68   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  2101d91e16687380154327107e992e
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 72 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]

# %%
productId_list = []
title_list = []
price_list = []
sold_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['trade']['tradeDesc']))
    sold_list.append(each_value)
    
print(sold_list)
# Out:
# ['3256803290146743', '3256804697787771', '3256803464903182', '3256803305179821', '3256803298586233', '3256804428351342', '3256804146965002', '3256802423567155', '3256804583276496', '3256804683170661', '2251832572099386', '3256804614754103', '3256802144987986', '3256804096886433', '3256804733965261', '3256804296472645', '3256804552876588', '3256803361828219', '3256803636531347', '3256804117379244']
# ['2021 Wool wool slippers autumn and winter women comfortable home with warm indoor quiet soft bottom Hao-008-APEX', '2022 new large size linen slippers home couple indoor slippers wood floor cotton and linen home summer sandals pg-002', 'Fashion Spring Women Flats Shoes Leather Suede Lace Up Boat Shoes Round Toe Moccasins Loafers Ladies Driving Casual Sneakers', "2021 Spring new leisure one-word solid color beach slippers indoor drag fashion women's shoes SU02", 'Canvas shoes for children 2020 cloth shoes for boys and girls, sportswear shoesUG-51', '2022 the new leisure shoes lazy flat shoes', 'ZZFABER Barefoot Shoes Women Sneakers Flexible Ladies Casual Flats Unisex Aqua Shoes Soft Hiking Sports Running Shoes for Men', '2021 Fashion Women Black Sneakers 44 Chaussure Femme Women Sneakers Zipper Canvas Casual Shoes Woman Spring Ladies Shoe', "Leather slippers winter women's home slippers plush warm anti-slip AP3kuan", 'Shoes For Women 2022 Designer Luxury Loafers Suede Leather Flat Walking Shoes Simple Comfortable Free Shipping', 'EOFK Spring Autumn Women Derby Platform Gold Flats Brogue Leather Lace up Classic Bullock Footwear Female Oxford Shoes Lady', "autumn period and the new single shoes for women's shoes flat round head soft light and comfortable shoes", 'MIA 090 Shoes', "Women's Jersey Round Toe Soft Ladies Moccasins Breathable Comfortable Work Shoes Fashion Ladies Flat Lightweight Driving Loafers", '2022 new Female shoes summer new style sandals and slippers, soft bottom indoor baomao pg-006', "Spring 2022 new women's single heel thick heel", 'Cotton slippers ladies autumn and winter indoor wool slippers warm home cotton slippers anti-slip', 'Slippers female summer soft bottom household indoor non-slip feet couple bathroom bathing silent sandals and slippers YJ-6', 'Fujin 10cm Platform Wedge Sneakers Chunky Shoes Genuine Leather for Women Summer Shoes Spring Autumn Walking Sneakers Fashion', 'YJXKJY 2022 New England Style Fashion Vintage Metal Ring Buckle Natural Real Leather Round Head Loafers Women Flat Shoes Female']
# ['US $35.48', 'US $66.74', 'US $19.13', 'US $19.53', 'US $23.42', 'US $30.16', 'US $20.75', 'US $27.49', 'US $33.44', 'US $44.40', 'US $27.07', 'US $25.13', 'US $300.00', 'US $35.00', 'US $76.53', 'US $18.85', 'US $18.85', 'US $21.15', 'US $37.80', 'US $54.05']
# ['111 sold', '469 sold', '5 sold', '73 sold', '145 sold', '193 sold', '959 sold', '1848 sold', '154 sold', '191 sold', '256 sold', '84 sold', '80 sold', '22 sold', '56 sold', '41 sold', '37 sold', '80 sold', '679 sold', '82 sold']

# %%
columns = {'Product ID': productId_list, 'Title': title_list, 'Price': price_list, 'Number Sold': sold_list}
wflats_df = pd.DataFrame(columns)
wflats_df
# Out:
#           Product ID                                              Title  \
# 0   3256803290146743  2021 Wool wool slippers autumn and winter wome...
# 1   3256804697787771  2022 new large size linen slippers home couple...
# 2   3256803464903182  Fashion Spring Women Flats Shoes Leather Suede...
# 3   3256803305179821  2021 Spring new leisure one-word solid color b...
# 4   3256803298586233  Canvas shoes for children 2020 cloth shoes for...
# 5   3256804428351342         2022 the new leisure shoes lazy flat shoes
# 6   3256804146965002  ZZFABER Barefoot Shoes Women Sneakers Flexible...
# 7   3256802423567155  2021 Fashion Women Black Sneakers 44 Chaussure...
# 8   3256804583276496  Leather slippers winter women's home slippers ...
# 9   3256804683170661  Shoes For Women 2022 Designer Luxury Loafers S...
# 10  2251832572099386  EOFK Spring Autumn Women Derby Platform Gold F...
# 11  3256804614754103  autumn period and the new single shoes for wom...
# 12  3256802144987986                                      MIA 090 Shoes
# 13  3256804096886433  Women's Jersey Round Toe Soft Ladies Moccasins...
# 14  3256804733965261  2022 new Female shoes summer new style sandals...
# 15  3256804296472645     Spring 2022 new women's single heel thick heel
# 16  3256804552876588  Cotton slippers ladies autumn and winter indoo...
# 17  3256803361828219  Slippers female summer soft bottom household i...
# 18  3256803636531347  Fujin 10cm Platform Wedge Sneakers Chunky Shoe...
# 19  3256804117379244  YJXKJY 2022 New England Style Fashion Vintage ...
#
#          Price Number Sold
# 0    US $35.48    111 sold
# 1    US $66.74    469 sold
# 2    US $19.13      5 sold
# 3    US $19.53     73 sold
# 4    US $23.42    145 sold
# 5    US $30.16    193 sold
# 6    US $20.75    959 sold
# 7    US $27.49   1848 sold
# 8    US $33.44    154 sold
# 9    US $44.40    191 sold
# 10   US $27.07    256 sold
# 11   US $25.13     84 sold
# 12  US $300.00     80 sold
# 13   US $35.00     22 sold
# 14   US $76.53     56 sold
# 15   US $18.85     41 sold
# 16   US $18.85     37 sold
# 17   US $21.15     80 sold
# 18   US $37.80    679 sold
# 19   US $54.05     82 sold

# %% [markdown]
# ## Product IDs For Women's Backpacks

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/152401"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   676     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'image': {'imgUrl': '//ae04.alicdn.com/kf/Sc...  ...
#
#    data.searchResult.modsStyle.image.small_gap  \
# 0                                            2
#
#   data.searchResult.modsStyle.prices.decimal_point  \
# 0                                                .
#
#   data.searchResult.modsStyle.prices.comma_style  \
# 0                                              ,
#
#    data.searchResult.modsStyle.prices.symbol_position  \
# 0                                               left
#
#    data.searchResult._host data.searchResult.scm  data.searchResult.version  \
# 0  hippo.033003005227.us68   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  2101d8b516687380643595254ea74a
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 72 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]

# %%
productId_list = []
title_list = []
price_list = []
sold_list = []

for i in range (19):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)

for i in range (19):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)

for i in range (19):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)

for i in range (19):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['trade']['tradeDesc']))
    sold_list.append(each_value)
    
print(sold_list)
# Out:
# ['3256804564194017', '3256803606594743', '3256804493377690', '3256801517944910', '3256804500463793', '3256804168518180', '3256803185748053', '3256804591462618', '3256803087230234', '3256804286365609', '2251832660869352', '3256803467371017', '3256802101368648', '3256803467206452', '3256803716391785', '3256804408402212', '3256804440638356', '3256804623039238', '3256804671065647']
# ["2022 Fashion Ladies Travel Leather Backpack Women's Bag Solid Color Backpacks High Quality Black Leather Bags Student Schoolbag", 'Personalized Embroidered Toddler Backpack Bag Lightweight Plush Bear Bag Kids Custom Name Backpack Gift for Boys Girls Ladies', "Women's Travel Real Leather Shoulder Vintage Backpack 2022 Cowhide Backpack Female Bag Genuine Bag Black School Fashion Backbag", "2021 Fashion New Mini Mink Hair Coin Purse Crossbody Small Bag Mobile Phone Bag All-Matching Women's Shoulder Mobile Phone Bag", 'School Bags Backpacks for Kids Girls Sweet Cute Embroidered Fruit Strawberry Lace Female Students Schoolbags Mochilas Para Mujer', 'Demon Slayer Nezuko Backpacks for Men Anime School Bag for Teenager Canvas Laptop Back Pack Women Rucksack Anime Nezuko Backpack', 'Japanese High School Girls Backpack School Bags For Teenage Girls Multi Pockets New Kawaii Backpack Women Harajuku Cute Mochila', "Women Backpack Purse Leather Anti-theft Casual Shoulder Bag Mochilas Satchel Bolso Female Genuine Backpacks For Students Women's", 'Tamara 2020 Luxury Genuine Leather Women Bag For Messenger Shoulder Bags Crossbody Lady Handbags Cowhide Platinum Bag', "Portable Fashion Girls Backpacks For Students Drawstring Backpack Santa Claus Christmas Women's Backpack Letter High Capacity", 'DIINOVIVO Fashion Skeleton Bear Female Backpack Punk Style School Bags Designer Backpacks for Adolescent Girls Gifts WHDV0324', 'Personalized Embroidery Toddler Backpack Lightweight Plush Bear Preschool Bag Kids Custom Name Backpack for Boys Girls Ladies', 'Nopersonality Flower And Moon Print Women Backpacks High Capacity Teen Girls Travel Bagpack Waterproof Daily Backbags', "Personalised Embroidery Bear Backpack Embroidered Portable Children Travel Shopping Rucksack Women's Cute Bear Shoulder Backpack", 'Canvas Women School Backpacks USB Charging Backpack Female Fashion School Bags for Young Girls Large Capacity Laptop Backpacks', 'Capacity Large Drawstring Bags Cartoon Panda Cute Backpack 2022 Year Casual Girls Bookbag Animal Printed Backpacks For Women', 'PINK Laser Backpack Girl School Bag Large Travel Pink Rucksack Lunch Bag', 'Personalised Bunny Backpack, Custom Name Cute Mini Backpacks for Girls Plush Rabbit Ear Satchel Fuzzy Bunny Purse Handbags', '10-Person Family Camping Tent, 3 Rooms and Screen Porch Tents Outdoor Camping Waterproof Hiking Survival Party Tent Backpacking']
# ['US $36.11', 'US $9.29', 'US $40.50', 'US $30.60', 'US $13.06', 'US $20.53', 'US $18.56', 'US $27.33', 'US $46.74', 'US $9.99', 'US $29.94', 'US $9.29', 'US $32.62', 'US $9.29', 'US $16.88', 'US $9.99', 'US $10.80', 'US $18.14', 'US $77.22']
# ['28 sold', '573 sold', '58 sold', '64 sold', '8 sold', '473 sold', '2442 sold', '25 sold', '48 sold', '3 sold', '424 sold', '1221 sold', '5 sold', '2027 sold', '154 sold', '28 sold', '12 sold', '3 sold', '4 sold']

# %%
columns = {'Product ID': productId_list, 'Title': title_list, 'Price': price_list, 'Number Sold': sold_list}
wbackpacks_df = pd.DataFrame(columns)
wbackpacks_df
# Out:
#           Product ID                                              Title  \
# 0   3256804564194017  2022 Fashion Ladies Travel Leather Backpack Wo...
# 1   3256803606594743  Personalized Embroidered Toddler Backpack Bag ...
# 2   3256804493377690  Women's Travel Real Leather Shoulder Vintage B...
# 3   3256801517944910  2021 Fashion New Mini Mink Hair Coin Purse Cro...
# 4   3256804500463793  School Bags Backpacks for Kids Girls Sweet Cut...
# 5   3256804168518180  Demon Slayer Nezuko Backpacks for Men Anime Sc...
# 6   3256803185748053  Japanese High School Girls Backpack School Bag...
# 7   3256804591462618  Women Backpack Purse Leather Anti-theft Casual...
# 8   3256803087230234  Tamara 2020 Luxury Genuine Leather Women Bag F...
# 9   3256804286365609  Portable Fashion Girls Backpacks For Students ...
# 10  2251832660869352  DIINOVIVO Fashion Skeleton Bear Female Backpac...
# 11  3256803467371017  Personalized Embroidery Toddler Backpack Light...
# 12  3256802101368648  Nopersonality Flower And Moon Print Women Back...
# 13  3256803467206452  Personalised Embroidery Bear Backpack Embroide...
# 14  3256803716391785  Canvas Women School Backpacks USB Charging Bac...
# 15  3256804408402212  Capacity Large Drawstring Bags Cartoon Panda C...
# 16  3256804440638356  PINK Laser Backpack Girl School Bag Large Trav...
# 17  3256804623039238  Personalised Bunny Backpack, Custom Name Cute ...
# 18  3256804671065647  10-Person Family Camping Tent, 3 Rooms and Scr...
#
#         Price Number Sold
# 0   US $36.11     28 sold
# 1    US $9.29    573 sold
# 2   US $40.50     58 sold
# 3   US $30.60     64 sold
# 4   US $13.06      8 sold
# 5   US $20.53    473 sold
# 6   US $18.56   2442 sold
# 7   US $27.33     25 sold
# 8   US $46.74     48 sold
# 9    US $9.99      3 sold
# 10  US $29.94    424 sold
# 11   US $9.29   1221 sold
# 12  US $32.62      5 sold
# 13   US $9.29   2027 sold
# 14  US $16.88    154 sold
# 15   US $9.99     28 sold
# 16  US $10.80     12 sold
# 17  US $18.14      3 sold
# 18  US $77.22      4 sold

# %% [markdown]
# ## Product IDs For Women's Wallets

# %%
url = "https://ali-express1.p.rapidapi.com/productsByCategoryV2/152405"

querystring = {"sort_type":"default","page":"1","page_size":"20","sort_order":"default"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df
# Out:
#    code  cost  success data.abVersion  data.crawler  \
# 0   200   647     True              1         False
#
#    data.searchResult.mods.searchRapidFilters.content  \
# 0  [{'paramType': 'List', 'rapidTiling': True, 'i...
#
#   data.searchResult.mods.searchRefineFilters.content  \
# 0  [{'paramType': 'String', 'rapidTiling': False,...
#
#   data.searchResult.mods.sortBar.tItemType  \
# 0                    nt_mainsearch_sortbar
#
#               data.searchResult.mods.sortBar.content  \
# 0  [{'sortOrders': [{'selected': True, 'order': '...
#
#              data.searchResult.mods.itemList.content  ...  \
# 0  [{'image': {'imgUrl': 'https://ae04.alicdn.com...  ...
#
#    data.searchResult.modsStyle.image.small_gap  \
# 0                                            2
#
#   data.searchResult.modsStyle.prices.decimal_point  \
# 0                                                .
#
#   data.searchResult.modsStyle.prices.comma_style  \
# 0                                              ,
#
#    data.searchResult.modsStyle.prices.symbol_position  \
# 0                                               left
#
#    data.searchResult._host data.searchResult.scm  data.searchResult.version  \
# 0  hippo.033001219117.us44   1007.28539.297875.0                        1.0
#
#    data.searchResult.srpResult     data.searchResult.tpp_trace  \
# 0                         [20]  2101d4a716687398431706947e99e1
#
#   data.trafficChannel
# 0                main
#
# [1 rows x 72 columns]

# %%
df = df[['data.searchResult.mods.itemList.content']]

# %%
productId_list = []
title_list = []
price_list = []
sold_list = []

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['productId']))
    
    productId_list.append(each_value)

print(productId_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['title']['displayTitle']))
    title_list.append(each_value)
    
print(title_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['prices']['salePrice']['formattedPrice']))
    price_list.append(each_value)
    
print(price_list)

for i in range (20):
    each_value = ((df["data.searchResult.mods.itemList.content"].values[0][i]['trade']['tradeDesc']))
    sold_list.append(each_value)
    
print(sold_list)
# Out:
# ['2251832771602462', '2255800322886034', '3256801748145050', '3256804096753971', '3256801374824803', '2255800012696097', '2251832662703142', '2251832777189136', '3256804319645969', '3256803643453073', '3256803809521467', '3256804255240199', '3256801435293429', '3256803308785671', '3256802052370126', '3256803457031773', '3256804096686046', '3256804505138540', '3256801851774803', '3256802590316293']
# ['DIENQI Rfid Smart Wallet Card Holder Metal Thin Slim Men Women Wallets Pop Up Minimalist Wallet Small Black Purse Metal Vallet', 'Custom Name Business Bank Credit Card Holder Men Wallet Coin Leather Wallet RFID Aluminium Box CardHolder with Money Clips Purse', 'Wallet PU Phone Case For Samsung Galaxy S8 S9 S10 S21 S22 S21FE A10 A12 A20 A30 A31 A32 A41 A42 A50 A52 A70 A72', 'Cartoon Wallet PU Leather Short Wallets Money Cards Holder Purse for Men Boy Kids', 'New Men women smart RFID wallet Card Holder fashion purse Aluminum alloy Business Credit Bank Card Holder Casual Mini wallet', 'DIENQI Carbon Fiber Card Holder Wallets Men Brand Rfid Black Magic Trifold Leather Slim Mini Wallet Small Money Bag Male Purses', 'Various Color 3D Print Wallets carteira PVC Folded Purse with Coin Pocket Creative Gift for Male Female Game Boy Wallet', 'Rfid Card Holder Wallets for Men Money Bag Male Short Leather Walet Small Slim Leather Smart Thin Wallets Purse Drop Shipping', 'Carbon Fiber Rfid Card Holder Men Wallets Money Bag Zipper Coin Purse Small Leather Mini Slim Wallets Vallet Carteira Masculina', 'Men Soft PU Leather Black White Solid Color Simple Short Ultra-thin Small Wallets Multi-card Slots Card Holder Small Coin Purse', 'Redmi Note 11 Case Leather Wallet Flip Cover Redmi Note 11s Phone Case For Redmi Note 11 Pro 5G 10 10s 9s 9 Flip Cover', 'Women Short Wallet Small Fashion Luxury Brand Leather Purse Ladies Card Bag For Women Clutch Female Purse Money Clip Wallet 2022', "Personalized Wallet Men High Quality PU Leather for Him Engraved Wallets Men Short Purse Custom Photo Wallet Father's Day Gift", 'Personalized Custom Photo Wallet for Men with Zipper Coin Pocket Engraved Picture & Text Wallets Christmas Gift for Him', 'Personalized Wallets Men High Quality PU Leather for Him Engraved Wallets Men Short Purse Custom Photo Wallet Luxury Men Gift', 'Rfid Airtag Wallet Money Bag Leather Card Holder Small Men Women Wallets Small Purse Air Tags Case Bag For Apple AirTags Tracker', 'Hot Japanese Anime Cartoon Wallet Cute Short Purse With Card Holder Coin Pocket', 'Hot Game XBOX Wallet Bi-Fold Male Short Purse ID Credit Card Holder', 'Wallet PU Leather Phone Case Cover For iPhone 6 6S 7 8 Plus X XS XR XSMax SE2020 11 12 13 14 Mini Pro ProMax', 'PU Anime Cartoon Game Wallet Short Purse For Young With Card Holder Coin Pocket']
# ['US $4.25', 'US $0.01', 'US $8.88', 'US $4.69', 'US $0.01', 'US $4.98', 'US $4.99', 'US $4.98', 'US $4.98', 'US $2.97', 'US $4.74', 'US $4.64', 'US $11.59', 'US $10.95', 'US $11.30', 'US $2.99', 'US $4.69', 'US $4.69', 'US $8.88', 'US $4.99']
# ['11262 sold', '2626 sold', '289 sold', '223 sold', '11001 sold', '3793 sold', '114 sold', '1106 sold', '1250 sold', '257 sold', '876 sold', '4106 sold', '258 sold', '394 sold', '1901 sold', '345 sold', '15 sold', '27 sold', '215 sold', '33 sold']

# %%
columns = {'Product ID': productId_list, 'Title': title_list, 'Price': price_list, 'Number Sold': sold_list}
wwallets_df = pd.DataFrame(columns)
wwallets_df
# Out:
#           Product ID                                              Title  \
# 0   2251832771602462  DIENQI Rfid Smart Wallet Card Holder Metal Thi...
# 1   2255800322886034  Custom Name Business Bank Credit Card Holder M...
# 2   3256801748145050  Wallet PU Phone Case For Samsung Galaxy S8 S9 ...
# 3   3256804096753971  Cartoon Wallet PU Leather Short Wallets Money ...
# 4   3256801374824803  New Men women smart RFID wallet Card Holder fa...
# 5   2255800012696097  DIENQI Carbon Fiber Card Holder Wallets Men Br...
# 6   2251832662703142  Various Color 3D Print Wallets carteira PVC Fo...
# 7   2251832777189136  Rfid Card Holder Wallets for Men Money Bag Mal...
# 8   3256804319645969  Carbon Fiber Rfid Card Holder Men Wallets Mone...
# 9   3256803643453073  Men Soft PU Leather Black White Solid Color Si...
# 10  3256803809521467  Redmi Note 11 Case Leather Wallet Flip Cover R...
# 11  3256804255240199  Women Short Wallet Small Fashion Luxury Brand ...
# 12  3256801435293429  Personalized Wallet Men High Quality PU Leathe...
# 13  3256803308785671  Personalized Custom Photo Wallet for Men with ...
# 14  3256802052370126  Personalized Wallets Men High Quality PU Leath...
# 15  3256803457031773  Rfid Airtag Wallet Money Bag Leather Card Hold...
# 16  3256804096686046  Hot Japanese Anime Cartoon Wallet Cute Short P...
# 17  3256804505138540  Hot Game XBOX Wallet Bi-Fold Male Short Purse ...
# 18  3256801851774803  Wallet PU Leather Phone Case Cover For iPhone ...
# 19  3256802590316293  PU Anime Cartoon Game Wallet Short Purse For Y...
#
#         Price Number Sold
# 0    US $4.25  11262 sold
# 1    US $0.01   2626 sold
# 2    US $8.88    289 sold
# 3    US $4.69    223 sold
# 4    US $0.01  11001 sold
# 5    US $4.98   3793 sold
# 6    US $4.99    114 sold
# 7    US $4.98   1106 sold
# 8    US $4.98   1250 sold
# 9    US $2.97    257 sold
# 10   US $4.74    876 sold
# 11   US $4.64   4106 sold
# 12  US $11.59    258 sold
# 13  US $10.95    394 sold
# 14  US $11.30   1901 sold
# 15   US $2.99    345 sold
# 16   US $4.69     15 sold
# 17   US $4.69     27 sold
# 18   US $8.88    215 sold
# 19   US $4.99     33 sold

# %% [markdown]
# ## Combine DataFrames

# %%
productIds_complete_df = pd.concat([wshoes_df, wboots_df, wflats_df, wbackpacks_df, wwallets_df])

# %%
productIds_complete_df
# Out:
#           Product ID                                              Title  \
# 0   3256803290146743  2021 Wool wool slippers autumn and winter wome...
# 1   3256804146039143  Best Selling Smiley Face Ladies Warm Furry Hom...
# 2   3256802759707769  2022 Summer Women Fashion Personality Indoor H...
# 3   3256803411670824  Daddy shoes female Breathable Versatile Sports...
# 4   3256804697787771  2022 new large size linen slippers home couple...
# ..               ...                                                ...
# 15  3256803457031773  Rfid Airtag Wallet Money Bag Leather Card Hold...
# 16  3256804096686046  Hot Japanese Anime Cartoon Wallet Cute Short P...
# 17  3256804505138540  Hot Game XBOX Wallet Bi-Fold Male Short Purse ...
# 18  3256801851774803  Wallet PU Leather Phone Case Cover For iPhone ...
# 19  3256802590316293  PU Anime Cartoon Game Wallet Short Purse For Y...
#
#         Price Number Sold
# 0   US $35.48    111 sold
# 1    US $8.75    589 sold
# 2    US $6.90   1186 sold
# 3   US $16.50     74 sold
# 4   US $66.74    469 sold
# ..        ...         ...
# 15   US $2.99    345 sold
# 16   US $4.69     15 sold
# 17   US $4.69     27 sold
# 18   US $8.88    215 sold
# 19   US $4.99     33 sold
#
# [99 rows x 4 columns]

# %%
df = productIds_complete_df
df.head()
# Out:
#          Product ID                                              Title  \
# 0  3256803290146743  2021 Wool wool slippers autumn and winter wome...
# 1  3256804146039143  Best Selling Smiley Face Ladies Warm Furry Hom...
# 2  3256802759707769  2022 Summer Women Fashion Personality Indoor H...
# 3  3256803411670824  Daddy shoes female Breathable Versatile Sports...
# 4  3256804697787771  2022 new large size linen slippers home couple...
#
#        Price Number Sold
# 0  US $35.48    111 sold
# 1   US $8.75    589 sold
# 2   US $6.90   1186 sold
# 3  US $16.50     74 sold
# 4  US $66.74    469 sold

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='productIds_bycategory.csv')  
df.to_csv('productIds_bycategory.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('productIds_bycategory.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)

# %% [markdown]
# ## Combine All Categories

# %%
data = np.array([[3256802423567155,
 3256803147612333,
 3256803313822268,
 3256803613454020,
 3256804146039143,
 3256804273010958,
 3256804288091339,
 3256804340338295,
 3256804374631137,
 3256804549567127,
 3256804564507961,
 3256804598834886,
 3256804600087452,
 3256804603507576,
 3256804606583693,
 3256804627451745,
 3256804679939115,
 3256804683170661,
 3256804697787771,
 3256804718617801], 
[3256803899670216,
 3256803910990175,
 3256804274369718,
 3256804288091339,
 3256804339852643,
 3256804374631137,
 3256804390450457,
 3256804419670610,
 3256804465546586,
 3256804536446371,
 3256804549567127,
 3256804603507576,
 3256804635290857,
 3256804676604636,
 3256804696130563,
 3256804698461319,
 3256804706160135,
 3256804710640068,
 3256804718617801,
 3256804728034603],
[3256802423567155,
 3256803290146743,
 3256803298586233,
 3256803305179821,
 3256803443967583,
 3256803448034929,
 3256803613454020,
 3256803636531347,
 3256803958419735,
 3256804096886433,
 3256804146965002,
 3256804520151422,
 3256804538602358,
 3256804583276496,
 3256804627451745,
 3256804679939115,
 3256804680467020,
 3256804683170661,
 3256804683702066,
 3256804697787771],
[2255800565385191,
 3256803193913624,
 3256803288474366,
 3256803380552863,
 3256803456568863,
 3256803852328051,
 3256804288946512,
 3256804345871208,
 3256804389102849,
 3256804398579682,
 3256804399002172,
 3256804456692695,
 3256804548714244,
 3256804558295955,
 3256804564507961,
 3256804588660403,
 3256804602698717,
 3256804622918647,
 3256804704992185,
 3256804705540267]])

dataset = pd.DataFrame({'Womens Shoes': data[0], 'Womens Boots': data[1], 'Women Flats': data[2], 'Mens Shoes': data[3]})
print(dataset)

# %%
df = pd.DataFrame(dataset)
df

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='productIds_bycategory.csv')  
df.to_csv('productIds_bycategory.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('productIds_bycategory.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)

# %% [markdown]
# ## Creating Product Feedback Database
# ### Plug in product IDs to compile and compare feedback within and between categories
# #### Keys to compare: "data.evaViewList.[0].buyerFeedback",  "data.evaViewList.[0].images", "data.productEvaluationStatistic."

# %%
url = "https://ali-express1.p.rapidapi.com/product/3256802423567155/feedback/"

querystring = {"country":"us","page":"1","type":"all"}

headers = {
	"X-RapidAPI-Key": "d60b547ecbmshfef17f77d83986cp115e1ajsne03176a7f3a6",
	"X-RapidAPI-Host": "ali-express1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
json = response.json()

# %%
df = pd.DataFrame(json)

# %%
df.to_csv(index=False)

compression_opts = dict(method='zip', archive_name='out.csv')  
df.to_csv('out.zip', index=False, compression=compression_opts) 

from pathlib import Path  
filepath = Path('out.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)  

# set path to file
p = Path('out.csv')

# read json
with p.open('r', encoding='utf-8') as f:
    data = json

# create dataframe
df = pd.json_normalize(data)
df

# %%
df = df[['data.evaViewList',
'data.productEvaluationStatistic.evarageStar',
'data.productEvaluationStatistic.evarageStarRage',
'data.productEvaluationStatistic.fiveStarNum',
'data.productEvaluationStatistic.fiveStarRate',
'data.productEvaluationStatistic.fourStarNum',
'data.productEvaluationStatistic.fourStarRate',
'data.productEvaluationStatistic.negativeNum',
'data.productEvaluationStatistic.negativeRate',
'data.productEvaluationStatistic.neutralNum',
'data.productEvaluationStatistic.neutralRate',
'data.productEvaluationStatistic.oneStarNum',
'data.productEvaluationStatistic.oneStarRate',
'data.productEvaluationStatistic.positiveNum',
'data.productEvaluationStatistic.positiveRate',
'data.productEvaluationStatistic.threeStarNum',
'data.productEvaluationStatistic.threeStarRate',
'data.productEvaluationStatistic.totalNum',
'data.productEvaluationStatistic.twoStarNum',
'data.productEvaluationStatistic.twoStarRate',]]
        
df

# %%
print((df["data.evaViewList"].values[0][0]['buyerFeedback']))

# %%
print((df["data.evaViewList"].values[0][0]['images']))

# %% [markdown]
# ### Ended up pasting feedback results per product id into csv files for each category

# %%
# df.to_excel("output.xlsx",
#              sheet_name='Sheet_name_1')

# %% [markdown]
#  ## Product IDs

# %%
 
    Womens Shoes      Womens Boots       Women Flats        Mens Shoes
0   3256802423567155  3256803899670216  3256802423567155  2255800565385191
1   3256803147612333  3256803910990175  3256803290146743  3256803193913624
2   3256803313822268  3256804274369718  3256803298586233  3256803288474366
3   3256803613454020  3256804288091339  3256803305179821  3256803380552863
4   3256804146039143  3256804339852643  3256803443967583  3256803456568863
5   3256804273010958  3256804374631137  3256803448034929  3256803852328051
6   3256804288091339  3256804390450457  3256803613454020  3256804288946512
7   3256804340338295  3256804419670610  3256803636531347  3256804345871208
8   3256804374631137  3256804465546586  3256803958419735  3256804389102849
9   3256804549567127  3256804536446371  3256804096886433  3256804398579682
10  3256804564507961  3256804549567127  3256804146965002  3256804399002172
11  3256804598834886  3256804603507576  3256804520151422  3256804456692695
12  3256804600087452  3256804635290857  3256804538602358  3256804548714244
13  3256804603507576  3256804676604636  3256804583276496  3256804558295955
14  3256804606583693  3256804696130563  3256804627451745  3256804564507961
15  3256804627451745  3256804698461319  3256804679939115  3256804588660403
16  3256804679939115  3256804706160135  3256804680467020  3256804602698717
17  3256804683170661  3256804710640068  3256804683170661  3256804622918647
18  3256804697787771  3256804718617801  3256804683702066  3256804704992185
19  3256804718617801  3256804728034603  3256804697787771  3256804705540267

# %%
# my_list = df.columns.values.tolist()
# my_list
