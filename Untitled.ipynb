# %%
import pandas as pd

# %%
df = pd.read_csv (r'C:\Users\vande\Desktop\class_folder\Team4FinalProject\Womens_Clothing_E-Commerce_Reviews.csv', index_col = 0)
df.to_json (r'C:\Users\vande\Desktop\class_folder\Team4FinalProject\Womens_Clothing_E-Commerce_Reviews.json')

# %%
df
# Out:
#        Clothing ID  Age                                  Title  \
# 4              847   47                       Flattering shirt
# 17             853   41           Looks great with white pants
# 20             847   33                      Cute, crisp shirt
# 24             847   55                              Versatile
# 47             823   52                                    NaN
# ...            ...  ...                                    ...
# 20088          772   50                      Comfy sweatshirt!
# 21532          665   43                           So worth it!
# 22997          136   47  Charcoal, pale gray, a bit of silver!
# 23006          136   33                        Cute itsy socks
# 23011          136   36                            Super socks
#
#                                              Review Text  Rating  \
# 4      This shirt is very flattering to all due to th...       5
# 17     Took a chance on this blouse and so glad i did...       5
# ...
