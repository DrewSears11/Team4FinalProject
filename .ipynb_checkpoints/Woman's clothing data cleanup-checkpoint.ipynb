# %%
import pandas as pd

df = pd.read_csv ('Womens_Clothing_E-Commerce_Reviews.csv')
print(df)
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
df.fillna("untitled")
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                               untitled
# 1                                               untitled
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
# Create a Ratings list.
Rating = df["Rating"].tolist()
Rating
# Out:
# [4,
#  5,
#  3,
#  5,
#  5,
#  2,
#  5,
#  4,
#  5,
#  5,
#  3,
#  5,
#  5,
#  5,
#  3,
#  4,
#  3,
#  5,
#  5,
#  5,
#  4,
#  4,
#  2,
#  3,
#  5,
#  3,
#  2,
#  4,
#  5,
#  5,
#  5,
#  5,
#  5,
#  2,
#  5,
#  4,
#  4,
#  5,
#  5,
#  5,
#  4,
#  5,
#  5,
#  4,
#  5,
#  4,
#  5,
#  5,
#  5,
#  5,
#  4,
#  5,
#  3,
#  5,
#  4,
#  5,
#  2,
#  3,
#  4,
#  4,
#  5,
#  1,
#  5,
#  5,
#  5,
#  4,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  5,
#  4,
#  5,
#  5,
#  4,
#  2,
#  5,
#  4,
#  5,
#  5,
#  5,
#  5,
#  3,
#  1,
#  4,
#  4,
#  2,
#  4,
#  4,
#  5,
#  5,
#  5,
#  4,
#  5,
#  1,
#  1,
#  5,
#  3,
#  4,
#  4,
#  5,
#  2,
#  2,
#  5,
#  4,
#  4,
#  5,
#  5,
#  1,
#  3,
#  5,
#  5,
#  2,
#  4,
#  4,
#  5,
#  2,
#  5,
#  5,
#  5,
#  5,
#  5,
#  3,
#  3,
#  4,
#  5,
#  4,
#  5,
#  4,
#  3,
#  4,
#  5,
#  5,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  4,
#  5,
#  5,
#  3,
#  3,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  3,
#  3,
#  3,
#  5,
#  5,
#  3,
#  4,
#  4,
#  4,
#  1,
#  4,
#  5,
#  4,
#  3,
# ...

# %%
# Create bins in which to place values based Ratings
bins = [0, 1, 2, 3, 4, 5, 6]

# Create labels for these bins
group_labels = ["Negative", "Negative", "Negative", "Positive", "Positive", "Positive"]

# %%
# Slice the data and place it into bins
pd.cut(df["Rating"], bins, labels=group_labels, ordered=False).head()
# Out:
# 0    Positive
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Positive
# Name: Rating, dtype: category
# Categories (2, object): ['Negative', 'Positive']

# %%
# Place the data series into a new column inside of the DataFrame
df["Positive or Negative"] = pd.cut(df["Rating"], bins, labels=group_labels, ordered=False)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
for i in range (len(Rating)):
    
    if i > 3
        print (Positive)
        
    else:
        if i < 3
        print (Negative)
# Out:
#   File "C:\Users\sears\AppData\Local\Temp\ipykernel_41408\251069310.py", line 3
#     if i > 3
#             ^
# SyntaxError: invalid syntax
