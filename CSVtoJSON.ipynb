# %%
import pandas as pd
df = pd.read_csv (r'C:\Users\vande\Desktop\class_folder\Team4FinalProject\Womens_Clothing_E-Commerce_Reviews.csv')
df.to_json (r'C:\Users\vande\Desktop\class_folder\Team4FinalProject\Womens_Clothing_E-Commerce_Reviews.json')

# %%
df
# Out:
#        Unnamed: 0  Clothing ID  Age                                  Title  \
# 0               4          847   47                       Flattering shirt
# 1              17          853   41           Looks great with white pants
# 2              20          847   33                      Cute, crisp shirt
# 3              24          847   55                              Versatile
# 4              47          823   52                                    NaN
# ...           ...          ...  ...                                    ...
# 23481       20088          772   50                      Comfy sweatshirt!
# 23482       21532          665   43                           So worth it!
# 23483       22997          136   47  Charcoal, pale gray, a bit of silver!
# 23484       23006          136   33                        Cute itsy socks
# 23485       23011          136   36                            Super socks
#
#                                              Review Text  Rating  \
# ...
